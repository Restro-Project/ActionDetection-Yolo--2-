# %% [markdown]
# # **Klasifikasi Gerakan untuk Rehabilitasi Stroke Menggunakan LSTM**
# Dataset yang akan digunakan adalah 10 video gerakan rehabilitasi untuk pasien stroke yang ditemukan di Internet.
#
# Proyek ini bertujuan untuk mendeteksi gerakan ....

# %% [markdown]
# # **1. Import Library**

# %%
pip install ultralytics opencv-python
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.145-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.7.2)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.3)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.0->ultralytics) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.0->ultralytics) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.23.0->ultralytics) (2024.2.0)
# Downloading ultralytics-8.3.145-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.9 MB/s eta 0:00:0000:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.0 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 11.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 8.8 MB/s eta 0:00:000:00:0100:01
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
#     Uninstalling nvidia-curand-cu12-10.3.10.19:
#       Successfully uninstalled nvidia-curand-cu12-10.3.10.19
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.4.0.6
#     Uninstalling nvidia-cufft-cu12-11.4.0.6:
#       Successfully uninstalled nvidia-cufft-cu12-11.4.0.6
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.9.0.13
#     Uninstalling nvidia-cublas-cu12-12.9.0.13:
#       Successfully uninstalled nvidia-cublas-cu12-12.9.0.13
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.9.5
#     Uninstalling nvidia-cusparse-cu12-12.5.9.5:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.9.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.4.40
#     Uninstalling nvidia-cusolver-cu12-11.7.4.40:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.4.40
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.145 ultralytics-thop-2.0.14
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install tensorflow

# %%
import os
import cv2
import pandas as pd
import numpy as np
import time
import seaborn as sns
import tensorflow as tf

from matplotlib import pyplot as plt
from tqdm import tqdm
from collections import defaultdict, deque
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, GRU, Conv1D, GlobalAveragePooling1D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# d:\1. Semester 7\LaskarAI\restro\ActionDetection-yolo\ActionDetection-Yolo\.venv\Scripts\python.exe
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
# !pip install seaborn matplotlib tqdm
# Out:
# Requirement already satisfied: seaborn in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.8.3)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.67.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# # **2. Memuat Dataset**

# %%
# Setup Folders for Collection
VIDEO_DIR = '/kaggle/input/dataset/dataset_video' 
sequence_length = 30         # frame per sequence
stride = sequence_length      
augment_mirror    = True     # hanya untuk train video
test_video_idx  = -1         # video ke-berapa per kelas utk hold-out (-1 = terakhir)
RANDOM_SEED     = 42
TRAIN_VIDS, TEST_VIDS = {}, {}

actions = sorted([d for d in os.listdir(VIDEO_DIR)
                  if os.path.isdir(os.path.join(VIDEO_DIR,d))])
print('Kelas terdeteksi:', actions, '\n')

vid_dict = defaultdict(list)   # {action: [video_path, …]}
for act in actions:
    for f in sorted(os.listdir(os.path.join(VIDEO_DIR,act))):
        if f.lower().endswith(('.mp4','.mov','.avi','.mkv')):
            vid_dict[act].append(os.path.join(VIDEO_DIR,act,f))
# Out:
# Kelas terdeteksi: ['Angkat Pinggul', 'Angkat Tangan', 'Lutut Turun', 'Naikan Kepalan Kedepan', 'Rentangkan']

# %% [markdown]
# # **3. Exploratory Data Analysis (EDA)**

# %%
print(os.listdir(VIDEO_DIR))
# Out:
# ['Rentangkan', 'Naikan Kepalan Kedepan', 'Lutut Turun', 'Angkat Pinggul', 'Angkat Tangan']

# %%
VIDEO_DIR = '/kaggle/input/dataset/dataset_video'
len(os.listdir(VIDEO_DIR))
# Out:
# 5

# %%
rows=[]
for act in actions:
    for vp in vid_dict[act]:
        cap=cv2.VideoCapture(vp)
        fps  = cap.get(cv2.CAP_PROP_FPS) or 30
        nfrm = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        dur  = nfrm/fps
        rows.append(dict(action=act, video=os.path.basename(vp),
                         fps=fps, frames=nfrm, duration=dur))
        cap.release()
df=pd.DataFrame(rows)
display(df)
sns.barplot(data=df,x='action',y='duration')
plt.xticks(rotation=45); plt.title('Durasi per Video'); plt.show()
# Out:
#                     action   video        fps  frames  duration
# 0           Angkat Pinggul   1.MOV  59.953704     259  4.320000
# 1           Angkat Pinggul  10.mp4  30.000000     104  3.466667
# 2           Angkat Pinggul   2.MOV  59.957326     281  4.686667
# 3           Angkat Pinggul   3.mp4  24.919779     146  5.858800
# 4           Angkat Pinggul   4.mp4  24.919583     149  5.979233
# 5           Angkat Pinggul   5.mp4  24.912027     202  8.108533
# 6           Angkat Pinggul   6.mp4  24.927840     114  4.573200
# 7           Angkat Pinggul   7.mp4  30.000000     139  4.633333
# 8           Angkat Pinggul   8.mp4  30.000000     157  5.233333
# 9           Angkat Pinggul   9.mp4  30.000000     145  4.833333
# 10           Angkat Tangan   1.mp4  24.926164     119  4.774100
# 11           Angkat Tangan  10.mp4  30.000000     108  3.600000
# 12           Angkat Tangan   2.mp4  24.936774      94  3.769533
# 13           Angkat Tangan   3.mp4  30.000000     134  4.466667
# 14           Angkat Tangan   4.mp4  30.000000      89  2.966667
# 15           Angkat Tangan   5.mp4  30.000000     112  3.733333
# 16           Angkat Tangan   6.mp4  30.000000     126  4.200000
# 17           Angkat Tangan   7.mp4  30.000000     112  3.733333
# 18           Angkat Tangan   8.mp4  30.000000     103  3.433333
# 19           Angkat Tangan   9.mp4  30.000000     111  3.700000
# 20             Lutut Turun   1.MOV  59.957627     283  4.720000
# 21             Lutut Turun  10.mp4  30.000000      89  2.966667
# 22             Lutut Turun   2.MOV  59.955752     271  4.520000
# 23             Lutut Turun   3.mp4  24.924060     128  5.135600
# 24             Lutut Turun   4.mp4  24.925291     124  4.974867
# 25             Lutut Turun   5.mp4  24.924060     128  5.135600
# 26             Lutut Turun   6.mp4  24.932373     102  4.091067
# 27             Lutut Turun   7.mp4  30.000000     151  5.033333
# 28             Lutut Turun   8.mp4  30.000000     148  4.933333
# 29             Lutut Turun   9.mp4  30.000000     125  4.166667
# 30  Naikan Kepalan Kedepan   1.mp4  24.928120     113  4.533033
# 31  Naikan Kepalan Kedepan  10.mp4  30.000000     154  5.133333
# 32  Naikan Kepalan Kedepan   2.mp4  24.918153     154  6.180233
# 33  Naikan Kepalan Kedepan   3.mp4  24.924060     128  5.135600
# 34  Naikan Kepalan Kedepan   4.mp4  24.917590     160  6.421167
# 35  Naikan Kepalan Kedepan   5.MOV  59.956395     275  4.586667
# 36  Naikan Kepalan Kedepan   6.MOV  59.956553     276  4.603333
# 37  Naikan Kepalan Kedepan   7.mp4  30.000000     214  7.133333
# 38  Naikan Kepalan Kedepan   8.mp4  30.000000     136  4.533333
# 39  Naikan Kepalan Kedepan   9.mp4  30.000000     166  5.533333
# 40              Rentangkan   1.mp4  24.933678      99  3.970533
# 41              Rentangkan  10.mp4  30.000000     146  4.866667
# 42              Rentangkan   2.mp4  24.927208     119  4.773900
# 43              Rentangkan   3.mp4  24.936774      94  3.769533
# 44              Rentangkan   4.mp4  24.923631     130  5.215933
# 45              Rentangkan   5.MOV  29.971182     156  5.205000
# 46              Rentangkan   6.MOV  59.970312     202  3.368333
# 47              Rentangkan   7.mp4  30.000000     142  4.733333
# 48              Rentangkan   8.mp4  30.000000     155  5.166667
# 49              Rentangkan   9.mp4  30.000000     103  3.433333

# %% [markdown]
# # **4. Preprocessing**

# %% [markdown]
# ### Ekstraksi Keypoints

# %%
import os
import cv2
import numpy as np
from ultralytics import YOLO
from tqdm import tqdm

# ---------------------------
# Inisialisasi Model YOLOv8
# ---------------------------
model = YOLO("/kaggle/input/yolo8n-pose/pytorch/default/1/yolov8n-pose.pt")  

# ---------------------------
# Pengaturan Folder
# ---------------------------
video_root = "/kaggle/input/dataset/dataset_video"  
keypoint_root = "keypoints"    

# Daftar aksi (label gerakan)
actions = ["Angkat Pinggul", "Angkat Tangan", "Lutut Turun", "Naikan Kepalan Kedepan", "Rentangkan"]

# ---------------------------
# Ekstraksi Keypoint
# ---------------------------
for action in actions:
    video_dir = os.path.join(video_root, action)
    save_dir = os.path.join(keypoint_root, action)
    os.makedirs(save_dir, exist_ok=True)

    for video_name in tqdm(os.listdir(video_dir), desc=f"Proses {action}"):
        video_path = os.path.join(video_dir, video_name)
        cap = cv2.VideoCapture(video_path)
        sequence = []

        while True:
            ret, frame = cap.read()
            if not ret:
                break

            results = model.predict(source=frame, conf=0.5, save=False, verbose=False)
            keypoints = results[0].keypoints

            if keypoints is not None and len(keypoints.xy) > 0:
                # Ambil keypoint orang pertama
                kps = keypoints.xy[0].cpu().numpy()  # shape: (17, 2)
                if kps.shape[0] == 17:  # pastikan 17 keypoints
                    sequence.append(kps.flatten())  # shape: (34,) = 17 keypoints × 2 (x, y)

        cap.release()

        # Simpan hanya jika ada keypoint valid
        if len(sequence) > 0:
            try:
                sequence = np.array(sequence)  # shape: (n_frames, 34)
                save_path = os.path.join(save_dir, video_name.replace(".MOV", ".npy").replace(".mp4", ".npy"))
                np.save(save_path, sequence)
                print(f"✅ Keypoint disimpan: {save_path}")
            except ValueError as e:
                print(f"❌ Gagal menyimpan {video_name}: {e}")
        else:
            print(f"⚠️ Tidak ada keypoint di {video_name}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Proses Angkat Pinggul:  10%|█         | 1/10 [00:33<04:58, 33.19s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Pinggul/5.npy
# Proses Angkat Pinggul:  20%|██        | 2/10 [01:11<04:50, 36.37s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Pinggul/1.npy
# Proses Angkat Pinggul:  30%|███       | 3/10 [01:31<03:21, 28.80s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Pinggul/3.npy
# Proses Angkat Pinggul:  40%|████      | 4/10 [01:54<02:38, 26.34s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Pinggul/8.npy
# Proses Angkat Pinggul:  50%|█████     | 5/10 [02:34<02:36, 31.23s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Pinggul/2.npy
# Proses Angkat Pinggul:  60%|██████    | 6/10 [02:57<01:53, 28.43s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Pinggul/9.npy
# Proses Angkat Pinggul:  70%|███████   | 7/10 [03:12<01:12, 24.33s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Pinggul/6.npy
# Proses Angkat Pinggul:  80%|████████  | 8/10 [03:43<00:52, 26.30s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Pinggul/4.npy
# Proses Angkat Pinggul:  90%|█████████ | 9/10 [03:58<00:22, 22.92s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Pinggul/10.npy
# Proses Angkat Pinggul: 100%|██████████| 10/10 [04:19<00:00, 25.93s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Pinggul/7.npy
# Proses Angkat Tangan:  10%|█         | 1/10 [00:14<02:12, 14.69s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Tangan/5.npy
# Proses Angkat Tangan:  20%|██        | 2/10 [00:32<02:12, 16.58s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Tangan/3.npy
# Proses Angkat Tangan:  30%|███       | 3/10 [00:46<01:46, 15.19s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Tangan/8.npy
# Proses Angkat Tangan:  40%|████      | 4/10 [01:00<01:28, 14.71s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Tangan/9.npy
# Proses Angkat Tangan:  50%|█████     | 5/10 [01:14<01:13, 14.67s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Tangan/1.npy
# Proses Angkat Tangan:  60%|██████    | 6/10 [01:31<01:01, 15.37s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Tangan/6.npy
# Proses Angkat Tangan:  70%|███████   | 7/10 [01:42<00:42, 14.03s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Tangan/4.npy
# Proses Angkat Tangan:  80%|████████  | 8/10 [01:55<00:27, 13.78s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Tangan/10.npy
# Proses Angkat Tangan:  90%|█████████ | 9/10 [02:10<00:14, 14.06s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Tangan/7.npy
# Proses Angkat Tangan: 100%|██████████| 10/10 [02:22<00:00, 14.20s/it]
# ✅ Keypoint disimpan: keypoints/Angkat Tangan/2.npy
# Proses Lutut Turun:  10%|█         | 1/10 [00:15<02:22, 15.88s/it]
# ✅ Keypoint disimpan: keypoints/Lutut Turun/5.npy
# Proses Lutut Turun:  20%|██        | 2/10 [00:51<03:41, 27.71s/it]
# ✅ Keypoint disimpan: keypoints/Lutut Turun/1.npy
# Proses Lutut Turun:  30%|███       | 3/10 [01:07<02:36, 22.39s/it]
# ✅ Keypoint disimpan: keypoints/Lutut Turun/3.npy
# Proses Lutut Turun:  40%|████      | 4/10 [01:26<02:05, 20.93s/it]
# ✅ Keypoint disimpan: keypoints/Lutut Turun/8.npy
# Proses Lutut Turun:  50%|█████     | 5/10 [02:01<02:09, 25.90s/it]
# ✅ Keypoint disimpan: keypoints/Lutut Turun/2.npy
# Proses Lutut Turun:  60%|██████    | 6/10 [02:17<01:30, 22.52s/it]
# ✅ Keypoint disimpan: keypoints/Lutut Turun/9.npy
# Proses Lutut Turun:  70%|███████   | 7/10 [02:33<01:01, 20.51s/it]
# ✅ Keypoint disimpan: keypoints/Lutut Turun/6.npy
# Proses Lutut Turun:  80%|████████  | 8/10 [02:48<00:37, 18.69s/it]
# ✅ Keypoint disimpan: keypoints/Lutut Turun/4.npy
# Proses Lutut Turun:  90%|█████████ | 9/10 [03:00<00:16, 16.52s/it]
# ✅ Keypoint disimpan: keypoints/Lutut Turun/10.npy
# Proses Lutut Turun: 100%|██████████| 10/10 [03:18<00:00, 19.88s/it]
# ✅ Keypoint disimpan: keypoints/Lutut Turun/7.npy
# Proses Naikan Kepalan Kedepan:  10%|█         | 1/10 [00:15<02:16, 15.12s/it]
# ✅ Keypoint disimpan: keypoints/Naikan Kepalan Kedepan/3.npy
# Proses Naikan Kepalan Kedepan:  20%|██        | 2/10 [00:32<02:10, 16.36s/it]
# ✅ Keypoint disimpan: keypoints/Naikan Kepalan Kedepan/8.npy
# Proses Naikan Kepalan Kedepan:  30%|███       | 3/10 [01:08<02:56, 25.18s/it]
# ✅ Keypoint disimpan: keypoints/Naikan Kepalan Kedepan/6.npy
# Proses Naikan Kepalan Kedepan:  40%|████      | 4/10 [01:28<02:20, 23.50s/it]
# ✅ Keypoint disimpan: keypoints/Naikan Kepalan Kedepan/9.npy
# Proses Naikan Kepalan Kedepan:  50%|█████     | 5/10 [01:42<01:40, 20.00s/it]
# ✅ Keypoint disimpan: keypoints/Naikan Kepalan Kedepan/1.npy
# Proses Naikan Kepalan Kedepan:  60%|██████    | 6/10 [02:02<01:19, 19.93s/it]
# ✅ Keypoint disimpan: keypoints/Naikan Kepalan Kedepan/4.npy
# Proses Naikan Kepalan Kedepan:  70%|███████   | 7/10 [02:22<00:59, 19.84s/it]
# ✅ Keypoint disimpan: keypoints/Naikan Kepalan Kedepan/10.npy
# Proses Naikan Kepalan Kedepan:  80%|████████  | 8/10 [02:48<00:43, 21.81s/it]
# ✅ Keypoint disimpan: keypoints/Naikan Kepalan Kedepan/7.npy
# Proses Naikan Kepalan Kedepan:  90%|█████████ | 9/10 [03:22<00:25, 25.65s/it]
# ✅ Keypoint disimpan: keypoints/Naikan Kepalan Kedepan/5.npy
# Proses Naikan Kepalan Kedepan: 100%|██████████| 10/10 [03:40<00:00, 22.06s/it]
# ✅ Keypoint disimpan: keypoints/Naikan Kepalan Kedepan/2.npy
# Proses Rentangkan:  10%|█         | 1/10 [00:10<01:37, 10.78s/it]
# ✅ Keypoint disimpan: keypoints/Rentangkan/3.npy
# Proses Rentangkan:  20%|██        | 2/10 [00:30<02:06, 15.84s/it]
# ✅ Keypoint disimpan: keypoints/Rentangkan/8.npy
# Proses Rentangkan:  30%|███       | 3/10 [00:55<02:21, 20.17s/it]
# ✅ Keypoint disimpan: keypoints/Rentangkan/6.npy
# Proses Rentangkan:  40%|████      | 4/10 [01:08<01:43, 17.33s/it]
# ✅ Keypoint disimpan: keypoints/Rentangkan/9.npy
# Proses Rentangkan:  50%|█████     | 5/10 [01:20<01:16, 15.38s/it]
# ✅ Keypoint disimpan: keypoints/Rentangkan/1.npy
# Proses Rentangkan:  60%|██████    | 6/10 [01:36<01:02, 15.52s/it]
# ✅ Keypoint disimpan: keypoints/Rentangkan/4.npy
# Proses Rentangkan:  70%|███████   | 7/10 [01:54<00:48, 16.29s/it]
# ✅ Keypoint disimpan: keypoints/Rentangkan/10.npy
# Proses Rentangkan:  80%|████████  | 8/10 [02:13<00:34, 17.37s/it]
# ✅ Keypoint disimpan: keypoints/Rentangkan/7.npy
# Proses Rentangkan:  90%|█████████ | 9/10 [02:36<00:19, 19.05s/it]
# ✅ Keypoint disimpan: keypoints/Rentangkan/5.npy
# Proses Rentangkan: 100%|██████████| 10/10 [02:50<00:00, 17.10s/it]
# ✅ Keypoint disimpan: keypoints/Rentangkan/2.npy

# %%
import cv2
from ultralytics import YOLO

model = YOLO("yolov8n-pose.pt")

video_path = "/kaggle/input/dataset/dataset_video/Rentangkan/5.MOV"
cap = cv2.VideoCapture(video_path)

# Dapatkan ukuran frame
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Inisialisasi writer untuk menyimpan video hasil
out = cv2.VideoWriter('output_pose.mp4',
                      cv2.VideoWriter_fourcc(*'mp4v'),
                      fps, (frame_width, frame_height))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model.predict(source=frame, save=False, conf=0.3)
    annotated_frame = results[0].plot()
    out.write(annotated_frame)

cap.release()
out.release()
print("✅ Hasil berhasil disimpan ke output_pose.mp4")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n-pose.pt to 'yolov8n-pose.pt'...
# 100%|██████████| 6.52M/6.52M [00:00<00:00, 185MB/s]
# 0: 384x640 2 persons, 130.6ms
# Speed: 3.0ms preprocess, 130.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 118.3ms
# Speed: 4.3ms preprocess, 118.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 124.5ms
# Speed: 4.5ms preprocess, 124.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 123.2ms
# Speed: 3.3ms preprocess, 123.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 120.8ms
# Speed: 5.3ms preprocess, 120.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 121.5ms
# Speed: 3.0ms preprocess, 121.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 113.7ms
# Speed: 3.9ms preprocess, 113.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 116.6ms
# Speed: 3.0ms preprocess, 116.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.9ms
# Speed: 3.9ms preprocess, 126.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 122.1ms
# Speed: 3.3ms preprocess, 122.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 116.0ms
# Speed: 2.7ms preprocess, 116.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 127.5ms
# Speed: 2.6ms preprocess, 127.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 124.8ms
# Speed: 3.2ms preprocess, 124.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.2ms
# Speed: 9.8ms preprocess, 115.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.1ms
# Speed: 2.9ms preprocess, 126.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 128.6ms
# Speed: 3.1ms preprocess, 128.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.1ms
# Speed: 3.5ms preprocess, 170.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 121.9ms
# Speed: 3.2ms preprocess, 121.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 121.9ms
# Speed: 9.7ms preprocess, 121.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 117.7ms
# Speed: 2.8ms preprocess, 117.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 129.4ms
# Speed: 3.7ms preprocess, 129.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 129.5ms
# Speed: 3.0ms preprocess, 129.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 116.1ms
# Speed: 4.0ms preprocess, 116.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 121.1ms
# Speed: 3.0ms preprocess, 121.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 131.3ms
# Speed: 3.9ms preprocess, 131.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 112.7ms
# Speed: 4.1ms preprocess, 112.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 129.4ms
# Speed: 4.0ms preprocess, 129.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.9ms
# Speed: 4.4ms preprocess, 119.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.4ms
# Speed: 3.9ms preprocess, 119.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.2ms
# Speed: 3.7ms preprocess, 119.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 117.1ms
# Speed: 3.2ms preprocess, 117.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.1ms
# Speed: 2.8ms preprocess, 118.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 122.5ms
# Speed: 3.1ms preprocess, 122.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 127.2ms
# Speed: 3.1ms preprocess, 127.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.6ms
# Speed: 3.2ms preprocess, 118.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.1ms
# Speed: 3.2ms preprocess, 126.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 125.5ms
# Speed: 2.9ms preprocess, 125.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 114.7ms
# Speed: 2.8ms preprocess, 114.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 123.8ms
# Speed: 2.8ms preprocess, 123.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 122.7ms
# Speed: 3.1ms preprocess, 122.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.6ms
# Speed: 3.1ms preprocess, 115.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.8ms
# Speed: 2.9ms preprocess, 119.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 124.4ms
# Speed: 2.7ms preprocess, 124.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.7ms
# Speed: 3.0ms preprocess, 113.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.7ms
# Speed: 2.6ms preprocess, 119.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.0ms
# Speed: 3.1ms preprocess, 126.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 129.2ms
# Speed: 2.6ms preprocess, 129.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 158.3ms
# Speed: 6.1ms preprocess, 158.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.1ms
# Speed: 18.1ms preprocess, 166.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 156.7ms
# Speed: 6.0ms preprocess, 156.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 150.7ms
# Speed: 6.4ms preprocess, 150.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 130.6ms
# Speed: 5.6ms preprocess, 130.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 152.9ms
# Speed: 4.6ms preprocess, 152.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 145.0ms
# Speed: 4.7ms preprocess, 145.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 127.9ms
# Speed: 5.5ms preprocess, 127.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 142.3ms
# Speed: 4.5ms preprocess, 142.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 143.8ms
# Speed: 13.7ms preprocess, 143.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.1ms
# Speed: 14.9ms preprocess, 126.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.7ms
# Speed: 3.9ms preprocess, 113.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.4ms
# Speed: 3.8ms preprocess, 120.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.9ms
# Speed: 4.0ms preprocess, 115.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 111.6ms
# Speed: 3.8ms preprocess, 111.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 114.2ms
# Speed: 3.7ms preprocess, 114.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 112.7ms
# Speed: 3.9ms preprocess, 112.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.5ms
# Speed: 4.0ms preprocess, 113.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.6ms
# Speed: 3.8ms preprocess, 113.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 114.1ms
# Speed: 3.8ms preprocess, 114.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 125.0ms
# Speed: 3.7ms preprocess, 125.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 122.6ms
# Speed: 2.8ms preprocess, 122.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 123.4ms
# Speed: 3.1ms preprocess, 123.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 117.7ms
# Speed: 3.0ms preprocess, 117.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 123.7ms
# Speed: 3.1ms preprocess, 123.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.9ms
# Speed: 3.1ms preprocess, 120.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.9ms
# Speed: 3.0ms preprocess, 119.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 127.8ms
# Speed: 3.7ms preprocess, 127.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 144.3ms
# Speed: 16.1ms preprocess, 144.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.0ms
# Speed: 3.1ms preprocess, 120.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 124.1ms
# Speed: 2.9ms preprocess, 124.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.2ms
# Speed: 3.1ms preprocess, 126.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.6ms
# Speed: 4.3ms preprocess, 118.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 116.5ms
# Speed: 4.1ms preprocess, 116.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 114.4ms
# Speed: 3.8ms preprocess, 114.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.5ms
# Speed: 3.7ms preprocess, 107.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 111.4ms
# Speed: 3.9ms preprocess, 111.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 117.7ms
# Speed: 2.6ms preprocess, 117.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 114.1ms
# Speed: 2.7ms preprocess, 114.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.6ms
# Speed: 2.8ms preprocess, 120.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 124.8ms
# Speed: 2.8ms preprocess, 124.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.4ms
# Speed: 2.5ms preprocess, 113.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 122.7ms
# Speed: 3.0ms preprocess, 122.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 128.0ms
# Speed: 3.7ms preprocess, 128.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.0ms
# Speed: 3.2ms preprocess, 118.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 145.7ms
# Speed: 2.7ms preprocess, 145.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 123.6ms
# Speed: 3.1ms preprocess, 123.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.9ms
# Speed: 3.3ms preprocess, 118.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 117.6ms
# Speed: 2.9ms preprocess, 117.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 121.3ms
# Speed: 2.5ms preprocess, 121.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.0ms
# Speed: 3.6ms preprocess, 115.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 122.9ms
# Speed: 2.6ms preprocess, 122.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 114.3ms
# Speed: 4.1ms preprocess, 114.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 111.7ms
# Speed: 3.9ms preprocess, 111.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.8ms
# Speed: 3.6ms preprocess, 115.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 121.1ms
# Speed: 2.9ms preprocess, 121.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.3ms
# Speed: 3.8ms preprocess, 108.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 123.6ms
# Speed: 3.7ms preprocess, 123.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.3ms
# Speed: 3.8ms preprocess, 113.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.9ms
# Speed: 3.3ms preprocess, 120.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.3ms
# Speed: 2.8ms preprocess, 119.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 128.3ms
# Speed: 4.9ms preprocess, 128.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 117.0ms
# Speed: 2.7ms preprocess, 117.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 127.2ms
# Speed: 2.9ms preprocess, 127.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.7ms
# Speed: 3.8ms preprocess, 115.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.8ms
# Speed: 3.8ms preprocess, 119.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 128.9ms
# Speed: 3.7ms preprocess, 128.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 121.0ms
# Speed: 3.0ms preprocess, 121.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 110.5ms
# Speed: 4.0ms preprocess, 110.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 125.4ms
# Speed: 8.1ms preprocess, 125.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.6ms
# Speed: 3.9ms preprocess, 119.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 122.7ms
# Speed: 2.9ms preprocess, 122.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.1ms
# Speed: 9.5ms preprocess, 126.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 124.4ms
# Speed: 3.0ms preprocess, 124.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.5ms
# Speed: 3.0ms preprocess, 115.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 122.0ms
# Speed: 4.5ms preprocess, 122.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.7ms
# Speed: 4.3ms preprocess, 115.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 121.3ms
# Speed: 2.9ms preprocess, 121.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.2ms
# Speed: 3.7ms preprocess, 115.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.1ms
# Speed: 3.4ms preprocess, 119.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.8ms
# Speed: 3.0ms preprocess, 118.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 124.2ms
# Speed: 2.9ms preprocess, 124.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 124.7ms
# Speed: 3.0ms preprocess, 124.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.7ms
# Speed: 4.1ms preprocess, 109.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 121.9ms
# Speed: 3.0ms preprocess, 121.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 129.5ms
# Speed: 3.2ms preprocess, 129.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.0ms
# Speed: 2.6ms preprocess, 120.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.4ms
# Speed: 4.0ms preprocess, 119.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 131.2ms
# Speed: 3.6ms preprocess, 131.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 180.5ms
# Speed: 3.9ms preprocess, 180.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.6ms
# Speed: 2.8ms preprocess, 126.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.6ms
# Speed: 2.6ms preprocess, 118.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.0ms
# Speed: 3.6ms preprocess, 108.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 128.9ms
# Speed: 2.7ms preprocess, 128.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 124.2ms
# Speed: 4.3ms preprocess, 124.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.6ms
# Speed: 3.7ms preprocess, 113.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 112.2ms
# Speed: 4.1ms preprocess, 112.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.7ms
# Speed: 3.1ms preprocess, 119.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 125.6ms
# Speed: 3.7ms preprocess, 125.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.1ms
# Speed: 3.8ms preprocess, 115.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 121.5ms
# Speed: 3.3ms preprocess, 121.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.9ms
# Speed: 4.0ms preprocess, 120.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 116.6ms
# Speed: 3.7ms preprocess, 116.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.8ms
# Speed: 3.3ms preprocess, 120.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 114.8ms
# Speed: 2.8ms preprocess, 114.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.8ms
# Speed: 2.7ms preprocess, 120.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 129.7ms
# Speed: 3.3ms preprocess, 129.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 127.7ms
# Speed: 3.1ms preprocess, 127.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 123.9ms
# Speed: 3.1ms preprocess, 123.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Hasil berhasil disimpan ke output_pose.mp4

# %% [markdown]
# ### Persiapan Dataset untuk Training

# %%
import os
import numpy as np
from sklearn.model_selection import GroupShuffleSplit

# Misal direktori keypoints per aksi sudah ada
keypoint_root = "keypoints"
actions = ["Angkat Pinggul", "Angkat Tangan", "Lutut Turun", "Naikan Kepalan Kedepan", "Rentangkan"]

X, y, groups = [], [], []

# Loop untuk load semua data .npy
for idx, action in enumerate(actions):
    action_dir = os.path.join(keypoint_root, action)
    for file in os.listdir(action_dir):
        if file.endswith('.npy'):
            filepath = os.path.join(action_dir, file)
            seq = np.load(filepath)  # bentuk: (n_frames, n_features)
            
            # Bisa lakukan padding/truncation di sini supaya shape uniform
            # contoh: ambil 30 frames saja (atau padding jika kurang)
            desired_frames = 30
            if seq.shape[0] > desired_frames:
                seq = seq[:desired_frames, :]
            elif seq.shape[0] < desired_frames:
                pad_width = desired_frames - seq.shape[0]
                seq = np.pad(seq, ((0,pad_width),(0,0)), mode='constant')

            X.append(seq)
            y.append(idx)  # label encoded numerik
            groups.append(file.split('_')[0])  # misal grup berdasarkan nama file, bisa diubah sesuai kebutuhan

X = np.array(X)  # shape (N_samples, timesteps, features)
y = np.array(y)
groups = np.array(groups)

print("Data shape:", X.shape)
print("Labels shape:", y.shape)
print("Groups shape:", groups.shape)
# Out:
# Data shape: (50, 30, 34)
# Labels shape: (50,)
# Groups shape: (50,)

# %% [markdown]
# ### Split Data

# %%
# Fungsi augmentasi: tambahkan noise Gaussian pada keypoint
def augment_data(X, noise_level=0.01):
    noise = np.random.normal(loc=0.0, scale=noise_level, size=X.shape)
    X_aug = X + noise
    return X_aug

# %%
RANDOM_SEED = 42
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=RANDOM_SEED)

train_idx, val_idx = next(gss.split(X, y, groups))

X_train, y_train = X[train_idx], y[train_idx]
X_val, y_val = X[val_idx], y[val_idx]

print("Train shape:", X_train.shape)
print("Validation shape:", X_val.shape)

# Augmentasi hanya di data train
X_train_aug = augment_data(X_train, noise_level=0.01)
# Out:
# Train shape: (40, 30, 34)
# Validation shape: (10, 30, 34)

# %% [markdown]
# ### One-hot encode label

# %%
import sys
print(sys.version)
# Out:
# 3.9.21 (main, Dec 11 2024, 16:35:24) [MSC v.1929 64 bit (AMD64)]

# %%
num_classes = len(actions)
y_train = to_categorical(y_train, num_classes=num_classes)
y_val = to_categorical(y_val, num_classes=num_classes)

# Cek dimensi input dan output
print("X_train shape:", X_train_aug.shape)     # contoh: (jumlah_sample, 30, 34)
print("y_train shape:", y_train.shape)     # contoh: (jumlah_sample, num_classes)
# Out:
# X_train shape: (40, 30, 34)
# y_train shape: (40, 5)

# %% [markdown]
# # **5. Pembangunan Model**

# %% [markdown]
# ## **a. Pelatihan Model**

# %%
print("Shape y_train:", y_train.shape)
print("Shape y_val:", y_val.shape)
print("Jumlah kelas:", len(actions))
# Out:
# Shape y_train: (40, 5)
# Shape y_val: (10, 5)
# Jumlah kelas: 5

# %%
'''# Ambil nilai dari shape input untuk digunakan di model
sequence_length = X_train_aug.shape[1]         # contoh: 30
num_features = X_train_aug.shape[2]            # contoh: 34'''

# %%
from sklearn.preprocessing import StandardScaler

# Normalisasi data
scaler = StandardScaler()

# Flatten data agar bisa di-scaler, lalu reshape kembali
sequence_length = X_train_aug.shape[1]
feature_size = X_train_aug.shape[2]

X_train_flat = X_train_aug.reshape(-1, feature_size)
X_train_scaled = scaler.fit_transform(X_train_flat).reshape(-1, sequence_length, feature_size)

X_val_flat = X_val.reshape(-1, feature_size)
X_val_scaled = scaler.transform(X_val_flat).reshape(-1, sequence_length, feature_size)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

'''model_lstm = Sequential([
    # Lapisan LSTM pertama dengan normalisasi
    LSTM(64, return_sequences=True, input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])),
    BatchNormalization(),
    Dropout(0.2),

    # Lapisan LSTM kedua dengan normalisasi
    LSTM(64, return_sequences=False),
    BatchNormalization(),
    Dropout(0.2),

    # Fully connected layer dengan normalisasi
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),

    # Layer output dengan softmax untuk klasifikasi
    Dense(num_classes, activation='softmax')
])'''

model_lstm = Sequential([
    LSTM(32, return_sequences=False, input_shape=(X_train_aug.shape[1], X_train_aug.shape[2])),
    Dropout(0.2),
    
    Dense(32, activation='relu'),
    Dropout(0.2),
    
    Dense(num_classes, activation='softmax')
])

# Compile model
model_lstm.compile(
    optimizer=Adam(learning_rate=1e-2),
    loss='categorical_crossentropy',
    metrics=['categorical_accuracy']
)

# Callbacks untuk training
callbacks_lstm = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1),
    ModelCheckpoint('lstm_best.keras', monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(factor=0.5, patience=5, verbose=1)
]

# Training model
history_lstm = model_lstm.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=150,
    batch_size=4, 
    shuffle=True,
    callbacks=callbacks_lstm,
    verbose=2
)
# Out:
# c:\Users\Nabila\miniconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/150
#
# Epoch 1: val_loss improved from inf to 1.07688, saving model to lstm_best.keras
# 10/10 - 4s - 359ms/step - categorical_accuracy: 0.3750 - loss: 1.5690 - val_categorical_accuracy: 0.7000 - val_loss: 1.0769 - learning_rate: 0.0100
# Epoch 2/150
#
# Epoch 2: val_loss improved from 1.07688 to 0.77456, saving model to lstm_best.keras
# 10/10 - 1s - 74ms/step - categorical_accuracy: 0.6250 - loss: 1.0215 - val_categorical_accuracy: 0.8000 - val_loss: 0.7746 - learning_rate: 0.0100
# Epoch 3/150
#
# Epoch 3: val_loss improved from 0.77456 to 0.65637, saving model to lstm_best.keras
# 10/10 - 0s - 21ms/step - categorical_accuracy: 0.7000 - loss: 0.7428 - val_categorical_accuracy: 0.7000 - val_loss: 0.6564 - learning_rate: 0.0100
# Epoch 4/150
#
# Epoch 4: val_loss improved from 0.65637 to 0.58307, saving model to lstm_best.keras
# 10/10 - 0s - 20ms/step - categorical_accuracy: 0.7500 - loss: 0.5517 - val_categorical_accuracy: 0.6000 - val_loss: 0.5831 - learning_rate: 0.0100
# Epoch 5/150
#
# Epoch 5: val_loss did not improve from 0.58307
# 10/10 - 0s - 18ms/step - categorical_accuracy: 0.8750 - loss: 0.4495 - val_categorical_accuracy: 0.7000 - val_loss: 0.6242 - learning_rate: 0.0100
# Epoch 6/150
#
# Epoch 6: val_loss improved from 0.58307 to 0.32070, saving model to lstm_best.keras
# 10/10 - 0s - 22ms/step - categorical_accuracy: 0.8000 - loss: 0.5566 - val_categorical_accuracy: 0.8000 - val_loss: 0.3207 - learning_rate: 0.0100
# Epoch 7/150
#
# Epoch 7: val_loss did not improve from 0.32070
# 10/10 - 0s - 33ms/step - categorical_accuracy: 0.8500 - loss: 0.4150 - val_categorical_accuracy: 0.8000 - val_loss: 0.3615 - learning_rate: 0.0100
# Epoch 8/150
#
# Epoch 8: val_loss improved from 0.32070 to 0.19571, saving model to lstm_best.keras
# 10/10 - 0s - 35ms/step - categorical_accuracy: 0.8750 - loss: 0.3299 - val_categorical_accuracy: 0.9000 - val_loss: 0.1957 - learning_rate: 0.0100
# Epoch 9/150
#
# Epoch 9: val_loss did not improve from 0.19571
# 10/10 - 0s - 25ms/step - categorical_accuracy: 0.8250 - loss: 0.3327 - val_categorical_accuracy: 0.9000 - val_loss: 0.2633 - learning_rate: 0.0100
# Epoch 10/150
#
# Epoch 10: val_loss did not improve from 0.19571
# 10/10 - 0s - 27ms/step - categorical_accuracy: 0.8500 - loss: 0.3753 - val_categorical_accuracy: 0.9000 - val_loss: 0.2097 - learning_rate: 0.0100
# Epoch 11/150
#
# Epoch 11: val_loss improved from 0.19571 to 0.06174, saving model to lstm_best.keras
# 10/10 - 0s - 31ms/step - categorical_accuracy: 0.8250 - loss: 0.4040 - val_categorical_accuracy: 1.0000 - val_loss: 0.0617 - learning_rate: 0.0100
# Epoch 12/150
#
# Epoch 12: val_loss did not improve from 0.06174
# 10/10 - 0s - 17ms/step - categorical_accuracy: 0.8000 - loss: 0.3733 - val_categorical_accuracy: 1.0000 - val_loss: 0.1008 - learning_rate: 0.0100
# Epoch 13/150
#
# Epoch 13: val_loss did not improve from 0.06174
# 10/10 - 0s - 16ms/step - categorical_accuracy: 0.9000 - loss: 0.3573 - val_categorical_accuracy: 0.9000 - val_loss: 0.1676 - learning_rate: 0.0100
# Epoch 14/150
#
# Epoch 14: val_loss did not improve from 0.06174
# 10/10 - 0s - 18ms/step - categorical_accuracy: 0.8750 - loss: 0.3035 - val_categorical_accuracy: 0.9000 - val_loss: 0.1880 - learning_rate: 0.0100
# Epoch 15/150
#
# Epoch 15: val_loss did not improve from 0.06174
# 10/10 - 0s - 15ms/step - categorical_accuracy: 0.9000 - loss: 0.2128 - val_categorical_accuracy: 1.0000 - val_loss: 0.0867 - learning_rate: 0.0100
# Epoch 16/150
#
# Epoch 16: val_loss did not improve from 0.06174
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 10/10 - 0s - 15ms/step - categorical_accuracy: 0.9250 - loss: 0.2110 - val_categorical_accuracy: 0.9000 - val_loss: 0.1111 - learning_rate: 0.0100
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 11.

# %% [markdown]
# ## GRU

# %%
# Ambil dimensi input dari X_train
'''sequence_length = X_train.shape[1]  # jumlah langkah waktu (timesteps)
feature_size = X_train.shape[2]     # jumlah fitur per timestep'''

# Model GRU
model_gru = Sequential([
    GRU(128, return_sequences=True, input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])),
    BatchNormalization(),
    Dropout(0.4),

    GRU(128, return_sequences=True),
    BatchNormalization(),
    Dropout(0.4),

    GRU(64),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    Dense(len(actions), activation='softmax')  # Pastikan 'actions' adalah daftar label unik
])

# Kompilasi model
model_gru.compile(
    optimizer=Adam(1e-4),
    loss='categorical_crossentropy',
    metrics=['categorical_accuracy']
)

# Callback
callbacks_gru = [
    EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss'),
    ModelCheckpoint('gru_best.keras', monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(patience=5, factor=0.5, verbose=1)
]

# Training model
history_gru = model_gru.fit(
    X_train, y_train,
    epochs=150,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=callbacks_gru,
    verbose=2
)
# Out:
# c:\Users\Nabila\miniconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/150
#
# Epoch 1: val_loss improved from inf to 1.73678, saving model to gru_best.keras
# 2/2 - 12s - 6s/step - categorical_accuracy: 0.1500 - loss: 2.8933 - val_categorical_accuracy: 0.1000 - val_loss: 1.7368 - learning_rate: 1.0000e-04
# Epoch 2/150
#
# Epoch 2: val_loss improved from 1.73678 to 1.71160, saving model to gru_best.keras
# 2/2 - 0s - 169ms/step - categorical_accuracy: 0.2000 - loss: 3.4014 - val_categorical_accuracy: 0.1000 - val_loss: 1.7116 - learning_rate: 1.0000e-04
# Epoch 3/150
#
# Epoch 3: val_loss improved from 1.71160 to 1.69473, saving model to gru_best.keras
# 2/2 - 0s - 164ms/step - categorical_accuracy: 0.2250 - loss: 2.5348 - val_categorical_accuracy: 0.1000 - val_loss: 1.6947 - learning_rate: 1.0000e-04
# Epoch 4/150
#
# Epoch 4: val_loss improved from 1.69473 to 1.68171, saving model to gru_best.keras
# 2/2 - 0s - 177ms/step - categorical_accuracy: 0.2000 - loss: 2.6787 - val_categorical_accuracy: 0.1000 - val_loss: 1.6817 - learning_rate: 1.0000e-04
# Epoch 5/150
#
# Epoch 5: val_loss improved from 1.68171 to 1.66553, saving model to gru_best.keras
# 2/2 - 0s - 158ms/step - categorical_accuracy: 0.3000 - loss: 2.1423 - val_categorical_accuracy: 0.2000 - val_loss: 1.6655 - learning_rate: 1.0000e-04
# Epoch 6/150
#
# Epoch 6: val_loss improved from 1.66553 to 1.63716, saving model to gru_best.keras
# 2/2 - 0s - 154ms/step - categorical_accuracy: 0.1750 - loss: 2.3716 - val_categorical_accuracy: 0.2000 - val_loss: 1.6372 - learning_rate: 1.0000e-04
# Epoch 7/150
#
# Epoch 7: val_loss improved from 1.63716 to 1.61663, saving model to gru_best.keras
# 2/2 - 0s - 148ms/step - categorical_accuracy: 0.2500 - loss: 2.3657 - val_categorical_accuracy: 0.2000 - val_loss: 1.6166 - learning_rate: 1.0000e-04
# Epoch 8/150
#
# Epoch 8: val_loss improved from 1.61663 to 1.60059, saving model to gru_best.keras
# 2/2 - 0s - 155ms/step - categorical_accuracy: 0.2750 - loss: 2.6893 - val_categorical_accuracy: 0.2000 - val_loss: 1.6006 - learning_rate: 1.0000e-04
# Epoch 9/150
#
# Epoch 9: val_loss improved from 1.60059 to 1.58539, saving model to gru_best.keras
# 2/2 - 0s - 143ms/step - categorical_accuracy: 0.3250 - loss: 2.3301 - val_categorical_accuracy: 0.2000 - val_loss: 1.5854 - learning_rate: 1.0000e-04
# Epoch 10/150
#
# Epoch 10: val_loss improved from 1.58539 to 1.57080, saving model to gru_best.keras
# 2/2 - 0s - 148ms/step - categorical_accuracy: 0.3500 - loss: 2.2331 - val_categorical_accuracy: 0.3000 - val_loss: 1.5708 - learning_rate: 1.0000e-04
# Epoch 11/150
#
# Epoch 11: val_loss improved from 1.57080 to 1.55380, saving model to gru_best.keras
# 2/2 - 0s - 145ms/step - categorical_accuracy: 0.2500 - loss: 2.3202 - val_categorical_accuracy: 0.3000 - val_loss: 1.5538 - learning_rate: 1.0000e-04
# Epoch 12/150
#
# Epoch 12: val_loss improved from 1.55380 to 1.53522, saving model to gru_best.keras
# 2/2 - 0s - 150ms/step - categorical_accuracy: 0.3250 - loss: 2.0699 - val_categorical_accuracy: 0.3000 - val_loss: 1.5352 - learning_rate: 1.0000e-04
# Epoch 13/150
#
# Epoch 13: val_loss improved from 1.53522 to 1.51575, saving model to gru_best.keras
# 2/2 - 0s - 158ms/step - categorical_accuracy: 0.3500 - loss: 2.0746 - val_categorical_accuracy: 0.3000 - val_loss: 1.5157 - learning_rate: 1.0000e-04
# Epoch 14/150
#
# Epoch 14: val_loss improved from 1.51575 to 1.49313, saving model to gru_best.keras
# 2/2 - 0s - 161ms/step - categorical_accuracy: 0.3500 - loss: 1.7349 - val_categorical_accuracy: 0.3000 - val_loss: 1.4931 - learning_rate: 1.0000e-04
# Epoch 15/150
#
# Epoch 15: val_loss improved from 1.49313 to 1.47687, saving model to gru_best.keras
# 2/2 - 0s - 157ms/step - categorical_accuracy: 0.3500 - loss: 1.7054 - val_categorical_accuracy: 0.3000 - val_loss: 1.4769 - learning_rate: 1.0000e-04
# Epoch 16/150
#
# Epoch 16: val_loss improved from 1.47687 to 1.46111, saving model to gru_best.keras
# 2/2 - 0s - 145ms/step - categorical_accuracy: 0.4500 - loss: 1.7378 - val_categorical_accuracy: 0.3000 - val_loss: 1.4611 - learning_rate: 1.0000e-04
# Epoch 17/150
#
# Epoch 17: val_loss improved from 1.46111 to 1.44577, saving model to gru_best.keras
# 2/2 - 0s - 183ms/step - categorical_accuracy: 0.3750 - loss: 1.6788 - val_categorical_accuracy: 0.3000 - val_loss: 1.4458 - learning_rate: 1.0000e-04
# Epoch 18/150
#
# Epoch 18: val_loss improved from 1.44577 to 1.43057, saving model to gru_best.keras
# 2/2 - 0s - 168ms/step - categorical_accuracy: 0.3750 - loss: 1.9561 - val_categorical_accuracy: 0.3000 - val_loss: 1.4306 - learning_rate: 1.0000e-04
# Epoch 19/150
#
# Epoch 19: val_loss improved from 1.43057 to 1.41353, saving model to gru_best.keras
# 2/2 - 0s - 149ms/step - categorical_accuracy: 0.2750 - loss: 2.0271 - val_categorical_accuracy: 0.3000 - val_loss: 1.4135 - learning_rate: 1.0000e-04
# Epoch 20/150
#
# Epoch 20: val_loss improved from 1.41353 to 1.39835, saving model to gru_best.keras
# 2/2 - 0s - 142ms/step - categorical_accuracy: 0.4500 - loss: 1.6065 - val_categorical_accuracy: 0.4000 - val_loss: 1.3983 - learning_rate: 1.0000e-04
# Epoch 21/150
#
# Epoch 21: val_loss improved from 1.39835 to 1.38313, saving model to gru_best.keras
# 2/2 - 0s - 201ms/step - categorical_accuracy: 0.4000 - loss: 1.8099 - val_categorical_accuracy: 0.4000 - val_loss: 1.3831 - learning_rate: 1.0000e-04
# Epoch 22/150
#
# Epoch 22: val_loss improved from 1.38313 to 1.36965, saving model to gru_best.keras
# 2/2 - 0s - 141ms/step - categorical_accuracy: 0.4000 - loss: 1.7398 - val_categorical_accuracy: 0.4000 - val_loss: 1.3696 - learning_rate: 1.0000e-04
# Epoch 23/150
#
# Epoch 23: val_loss improved from 1.36965 to 1.35649, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.4500 - loss: 1.4379 - val_categorical_accuracy: 0.5000 - val_loss: 1.3565 - learning_rate: 1.0000e-04
# Epoch 24/150
#
# Epoch 24: val_loss improved from 1.35649 to 1.34294, saving model to gru_best.keras
# 2/2 - 0s - 136ms/step - categorical_accuracy: 0.5250 - loss: 1.4250 - val_categorical_accuracy: 0.5000 - val_loss: 1.3429 - learning_rate: 1.0000e-04
# Epoch 25/150
#
# Epoch 25: val_loss improved from 1.34294 to 1.32990, saving model to gru_best.keras
# 2/2 - 0s - 233ms/step - categorical_accuracy: 0.5500 - loss: 1.5314 - val_categorical_accuracy: 0.5000 - val_loss: 1.3299 - learning_rate: 1.0000e-04
# Epoch 26/150
#
# Epoch 26: val_loss improved from 1.32990 to 1.31648, saving model to gru_best.keras
# 2/2 - 0s - 145ms/step - categorical_accuracy: 0.4750 - loss: 1.3416 - val_categorical_accuracy: 0.5000 - val_loss: 1.3165 - learning_rate: 1.0000e-04
# Epoch 27/150
#
# Epoch 27: val_loss improved from 1.31648 to 1.30354, saving model to gru_best.keras
# 2/2 - 0s - 145ms/step - categorical_accuracy: 0.5500 - loss: 1.1246 - val_categorical_accuracy: 0.5000 - val_loss: 1.3035 - learning_rate: 1.0000e-04
# Epoch 28/150
#
# Epoch 28: val_loss improved from 1.30354 to 1.28618, saving model to gru_best.keras
# 2/2 - 0s - 140ms/step - categorical_accuracy: 0.4750 - loss: 1.4758 - val_categorical_accuracy: 0.6000 - val_loss: 1.2862 - learning_rate: 1.0000e-04
# Epoch 29/150
#
# Epoch 29: val_loss improved from 1.28618 to 1.27077, saving model to gru_best.keras
# 2/2 - 0s - 137ms/step - categorical_accuracy: 0.4000 - loss: 1.6002 - val_categorical_accuracy: 0.7000 - val_loss: 1.2708 - learning_rate: 1.0000e-04
# Epoch 30/150
#
# Epoch 30: val_loss improved from 1.27077 to 1.25348, saving model to gru_best.keras
# 2/2 - 0s - 143ms/step - categorical_accuracy: 0.3750 - loss: 1.4871 - val_categorical_accuracy: 0.8000 - val_loss: 1.2535 - learning_rate: 1.0000e-04
# Epoch 31/150
#
# Epoch 31: val_loss improved from 1.25348 to 1.23381, saving model to gru_best.keras
# 2/2 - 0s - 138ms/step - categorical_accuracy: 0.4750 - loss: 1.2689 - val_categorical_accuracy: 0.8000 - val_loss: 1.2338 - learning_rate: 1.0000e-04
# Epoch 32/150
#
# Epoch 32: val_loss improved from 1.23381 to 1.21392, saving model to gru_best.keras
# 2/2 - 0s - 139ms/step - categorical_accuracy: 0.4750 - loss: 1.5305 - val_categorical_accuracy: 0.8000 - val_loss: 1.2139 - learning_rate: 1.0000e-04
# Epoch 33/150
#
# Epoch 33: val_loss improved from 1.21392 to 1.19275, saving model to gru_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.5750 - loss: 1.0393 - val_categorical_accuracy: 0.8000 - val_loss: 1.1927 - learning_rate: 1.0000e-04
# Epoch 34/150
#
# Epoch 34: val_loss improved from 1.19275 to 1.17592, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.6000 - loss: 0.8840 - val_categorical_accuracy: 0.8000 - val_loss: 1.1759 - learning_rate: 1.0000e-04
# Epoch 35/150
#
# Epoch 35: val_loss improved from 1.17592 to 1.16408, saving model to gru_best.keras
# 2/2 - 0s - 197ms/step - categorical_accuracy: 0.5000 - loss: 1.4443 - val_categorical_accuracy: 0.8000 - val_loss: 1.1641 - learning_rate: 1.0000e-04
# Epoch 36/150
#
# Epoch 36: val_loss improved from 1.16408 to 1.15368, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.4500 - loss: 1.5320 - val_categorical_accuracy: 0.8000 - val_loss: 1.1537 - learning_rate: 1.0000e-04
# Epoch 37/150
#
# Epoch 37: val_loss improved from 1.15368 to 1.14422, saving model to gru_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.6000 - loss: 1.0147 - val_categorical_accuracy: 0.8000 - val_loss: 1.1442 - learning_rate: 1.0000e-04
# Epoch 38/150
#
# Epoch 38: val_loss improved from 1.14422 to 1.13023, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.4500 - loss: 1.3986 - val_categorical_accuracy: 0.8000 - val_loss: 1.1302 - learning_rate: 1.0000e-04
# Epoch 39/150
#
# Epoch 39: val_loss improved from 1.13023 to 1.11455, saving model to gru_best.keras
# 2/2 - 0s - 136ms/step - categorical_accuracy: 0.4500 - loss: 1.2298 - val_categorical_accuracy: 0.8000 - val_loss: 1.1145 - learning_rate: 1.0000e-04
# Epoch 40/150
#
# Epoch 40: val_loss improved from 1.11455 to 1.09597, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.7000 - loss: 0.9252 - val_categorical_accuracy: 0.8000 - val_loss: 1.0960 - learning_rate: 1.0000e-04
# Epoch 41/150
#
# Epoch 41: val_loss improved from 1.09597 to 1.07918, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.5000 - loss: 1.3953 - val_categorical_accuracy: 0.8000 - val_loss: 1.0792 - learning_rate: 1.0000e-04
# Epoch 42/150
#
# Epoch 42: val_loss improved from 1.07918 to 1.06037, saving model to gru_best.keras
# 2/2 - 0s - 139ms/step - categorical_accuracy: 0.7250 - loss: 0.7789 - val_categorical_accuracy: 0.8000 - val_loss: 1.0604 - learning_rate: 1.0000e-04
# Epoch 43/150
#
# Epoch 43: val_loss improved from 1.06037 to 1.04490, saving model to gru_best.keras
# 2/2 - 0s - 175ms/step - categorical_accuracy: 0.5750 - loss: 1.1329 - val_categorical_accuracy: 0.8000 - val_loss: 1.0449 - learning_rate: 1.0000e-04
# Epoch 44/150
#
# Epoch 44: val_loss improved from 1.04490 to 1.03117, saving model to gru_best.keras
# 2/2 - 0s - 138ms/step - categorical_accuracy: 0.6000 - loss: 1.1199 - val_categorical_accuracy: 0.9000 - val_loss: 1.0312 - learning_rate: 1.0000e-04
# Epoch 45/150
#
# Epoch 45: val_loss improved from 1.03117 to 1.01446, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.6750 - loss: 0.8384 - val_categorical_accuracy: 0.9000 - val_loss: 1.0145 - learning_rate: 1.0000e-04
# Epoch 46/150
#
# Epoch 46: val_loss improved from 1.01446 to 0.99914, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.7500 - loss: 0.8109 - val_categorical_accuracy: 0.9000 - val_loss: 0.9991 - learning_rate: 1.0000e-04
# Epoch 47/150
#
# Epoch 47: val_loss improved from 0.99914 to 0.98203, saving model to gru_best.keras
# 2/2 - 0s - 179ms/step - categorical_accuracy: 0.6000 - loss: 1.1391 - val_categorical_accuracy: 0.9000 - val_loss: 0.9820 - learning_rate: 1.0000e-04
# Epoch 48/150
#
# Epoch 48: val_loss improved from 0.98203 to 0.96675, saving model to gru_best.keras
# 2/2 - 0s - 137ms/step - categorical_accuracy: 0.6500 - loss: 0.9387 - val_categorical_accuracy: 0.9000 - val_loss: 0.9668 - learning_rate: 1.0000e-04
# Epoch 49/150
#
# Epoch 49: val_loss improved from 0.96675 to 0.95066, saving model to gru_best.keras
# 2/2 - 0s - 132ms/step - categorical_accuracy: 0.5500 - loss: 1.1767 - val_categorical_accuracy: 0.9000 - val_loss: 0.9507 - learning_rate: 1.0000e-04
# Epoch 50/150
#
# Epoch 50: val_loss improved from 0.95066 to 0.93535, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.7250 - loss: 0.5836 - val_categorical_accuracy: 0.9000 - val_loss: 0.9354 - learning_rate: 1.0000e-04
# Epoch 51/150
#
# Epoch 51: val_loss improved from 0.93535 to 0.91990, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.6500 - loss: 0.8442 - val_categorical_accuracy: 0.9000 - val_loss: 0.9199 - learning_rate: 1.0000e-04
# Epoch 52/150
#
# Epoch 52: val_loss improved from 0.91990 to 0.90293, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.6500 - loss: 0.8629 - val_categorical_accuracy: 0.9000 - val_loss: 0.9029 - learning_rate: 1.0000e-04
# Epoch 53/150
#
# Epoch 53: val_loss improved from 0.90293 to 0.88443, saving model to gru_best.keras
# 2/2 - 0s - 136ms/step - categorical_accuracy: 0.5750 - loss: 1.0593 - val_categorical_accuracy: 0.9000 - val_loss: 0.8844 - learning_rate: 1.0000e-04
# Epoch 54/150
#
# Epoch 54: val_loss improved from 0.88443 to 0.86734, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.6500 - loss: 0.9430 - val_categorical_accuracy: 0.9000 - val_loss: 0.8673 - learning_rate: 1.0000e-04
# Epoch 55/150
#
# Epoch 55: val_loss improved from 0.86734 to 0.84924, saving model to gru_best.keras
# 2/2 - 0s - 137ms/step - categorical_accuracy: 0.6500 - loss: 0.8952 - val_categorical_accuracy: 0.9000 - val_loss: 0.8492 - learning_rate: 1.0000e-04
# Epoch 56/150
#
# Epoch 56: val_loss improved from 0.84924 to 0.83281, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.7250 - loss: 0.6529 - val_categorical_accuracy: 0.9000 - val_loss: 0.8328 - learning_rate: 1.0000e-04
# Epoch 57/150
#
# Epoch 57: val_loss improved from 0.83281 to 0.81735, saving model to gru_best.keras
# 2/2 - 0s - 140ms/step - categorical_accuracy: 0.6500 - loss: 0.9341 - val_categorical_accuracy: 0.9000 - val_loss: 0.8173 - learning_rate: 1.0000e-04
# Epoch 58/150
#
# Epoch 58: val_loss improved from 0.81735 to 0.79143, saving model to gru_best.keras
# 2/2 - 0s - 141ms/step - categorical_accuracy: 0.7000 - loss: 0.9999 - val_categorical_accuracy: 0.9000 - val_loss: 0.7914 - learning_rate: 1.0000e-04
# Epoch 59/150
#
# Epoch 59: val_loss improved from 0.79143 to 0.76759, saving model to gru_best.keras
# 2/2 - 0s - 140ms/step - categorical_accuracy: 0.7750 - loss: 0.7321 - val_categorical_accuracy: 0.9000 - val_loss: 0.7676 - learning_rate: 1.0000e-04
# Epoch 60/150
#
# Epoch 60: val_loss improved from 0.76759 to 0.75260, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.7000 - loss: 0.8278 - val_categorical_accuracy: 0.9000 - val_loss: 0.7526 - learning_rate: 1.0000e-04
# Epoch 61/150
#
# Epoch 61: val_loss improved from 0.75260 to 0.73382, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.7500 - loss: 0.8366 - val_categorical_accuracy: 0.9000 - val_loss: 0.7338 - learning_rate: 1.0000e-04
# Epoch 62/150
#
# Epoch 62: val_loss improved from 0.73382 to 0.71597, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.6750 - loss: 0.7720 - val_categorical_accuracy: 0.9000 - val_loss: 0.7160 - learning_rate: 1.0000e-04
# Epoch 63/150
#
# Epoch 63: val_loss improved from 0.71597 to 0.69806, saving model to gru_best.keras
# 2/2 - 0s - 137ms/step - categorical_accuracy: 0.7000 - loss: 0.7028 - val_categorical_accuracy: 0.9000 - val_loss: 0.6981 - learning_rate: 1.0000e-04
# Epoch 64/150
#
# Epoch 64: val_loss improved from 0.69806 to 0.68106, saving model to gru_best.keras
# 2/2 - 0s - 136ms/step - categorical_accuracy: 0.7250 - loss: 0.7013 - val_categorical_accuracy: 0.9000 - val_loss: 0.6811 - learning_rate: 1.0000e-04
# Epoch 65/150
#
# Epoch 65: val_loss improved from 0.68106 to 0.66466, saving model to gru_best.keras
# 2/2 - 0s - 166ms/step - categorical_accuracy: 0.7000 - loss: 0.7330 - val_categorical_accuracy: 0.9000 - val_loss: 0.6647 - learning_rate: 1.0000e-04
# Epoch 66/150
#
# Epoch 66: val_loss improved from 0.66466 to 0.65011, saving model to gru_best.keras
# 2/2 - 0s - 148ms/step - categorical_accuracy: 0.7500 - loss: 0.7017 - val_categorical_accuracy: 0.9000 - val_loss: 0.6501 - learning_rate: 1.0000e-04
# Epoch 67/150
#
# Epoch 67: val_loss improved from 0.65011 to 0.63646, saving model to gru_best.keras
# 2/2 - 0s - 132ms/step - categorical_accuracy: 0.7750 - loss: 0.6269 - val_categorical_accuracy: 0.9000 - val_loss: 0.6365 - learning_rate: 1.0000e-04
# Epoch 68/150
#
# Epoch 68: val_loss improved from 0.63646 to 0.62443, saving model to gru_best.keras
# 2/2 - 0s - 188ms/step - categorical_accuracy: 0.7000 - loss: 0.7620 - val_categorical_accuracy: 0.9000 - val_loss: 0.6244 - learning_rate: 1.0000e-04
# Epoch 69/150
#
# Epoch 69: val_loss improved from 0.62443 to 0.61555, saving model to gru_best.keras
# 2/2 - 0s - 136ms/step - categorical_accuracy: 0.7750 - loss: 0.6432 - val_categorical_accuracy: 0.9000 - val_loss: 0.6155 - learning_rate: 1.0000e-04
# Epoch 70/150
#
# Epoch 70: val_loss improved from 0.61555 to 0.60727, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.8250 - loss: 0.5990 - val_categorical_accuracy: 0.9000 - val_loss: 0.6073 - learning_rate: 1.0000e-04
# Epoch 71/150
#
# Epoch 71: val_loss improved from 0.60727 to 0.59789, saving model to gru_best.keras
# 2/2 - 0s - 136ms/step - categorical_accuracy: 0.8500 - loss: 0.4824 - val_categorical_accuracy: 0.9000 - val_loss: 0.5979 - learning_rate: 1.0000e-04
# Epoch 72/150
#
# Epoch 72: val_loss improved from 0.59789 to 0.58502, saving model to gru_best.keras
# 2/2 - 0s - 138ms/step - categorical_accuracy: 0.7000 - loss: 0.8685 - val_categorical_accuracy: 0.9000 - val_loss: 0.5850 - learning_rate: 1.0000e-04
# Epoch 73/150
#
# Epoch 73: val_loss improved from 0.58502 to 0.57366, saving model to gru_best.keras
# 2/2 - 0s - 138ms/step - categorical_accuracy: 0.7750 - loss: 0.6057 - val_categorical_accuracy: 0.9000 - val_loss: 0.5737 - learning_rate: 1.0000e-04
# Epoch 74/150
#
# Epoch 74: val_loss improved from 0.57366 to 0.56387, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.7250 - loss: 0.7841 - val_categorical_accuracy: 0.9000 - val_loss: 0.5639 - learning_rate: 1.0000e-04
# Epoch 75/150
#
# Epoch 75: val_loss improved from 0.56387 to 0.54129, saving model to gru_best.keras
# 2/2 - 0s - 140ms/step - categorical_accuracy: 0.7250 - loss: 0.6621 - val_categorical_accuracy: 0.9000 - val_loss: 0.5413 - learning_rate: 1.0000e-04
# Epoch 76/150
#
# Epoch 76: val_loss improved from 0.54129 to 0.52215, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.8250 - loss: 0.5654 - val_categorical_accuracy: 0.9000 - val_loss: 0.5221 - learning_rate: 1.0000e-04
# Epoch 77/150
#
# Epoch 77: val_loss improved from 0.52215 to 0.50747, saving model to gru_best.keras
# 2/2 - 0s - 129ms/step - categorical_accuracy: 0.9000 - loss: 0.4858 - val_categorical_accuracy: 0.9000 - val_loss: 0.5075 - learning_rate: 1.0000e-04
# Epoch 78/150
#
# Epoch 78: val_loss improved from 0.50747 to 0.49543, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.7000 - loss: 0.8244 - val_categorical_accuracy: 0.9000 - val_loss: 0.4954 - learning_rate: 1.0000e-04
# Epoch 79/150
#
# Epoch 79: val_loss improved from 0.49543 to 0.48920, saving model to gru_best.keras
# 2/2 - 0s - 129ms/step - categorical_accuracy: 0.7750 - loss: 0.6324 - val_categorical_accuracy: 0.9000 - val_loss: 0.4892 - learning_rate: 1.0000e-04
# Epoch 80/150
#
# Epoch 80: val_loss improved from 0.48920 to 0.48357, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.8500 - loss: 0.5739 - val_categorical_accuracy: 0.9000 - val_loss: 0.4836 - learning_rate: 1.0000e-04
# Epoch 81/150
#
# Epoch 81: val_loss improved from 0.48357 to 0.47849, saving model to gru_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.7750 - loss: 0.6123 - val_categorical_accuracy: 0.9000 - val_loss: 0.4785 - learning_rate: 1.0000e-04
# Epoch 82/150
#
# Epoch 82: val_loss improved from 0.47849 to 0.47267, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.8250 - loss: 0.4464 - val_categorical_accuracy: 0.9000 - val_loss: 0.4727 - learning_rate: 1.0000e-04
# Epoch 83/150
#
# Epoch 83: val_loss improved from 0.47267 to 0.46592, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.7250 - loss: 0.6279 - val_categorical_accuracy: 0.9000 - val_loss: 0.4659 - learning_rate: 1.0000e-04
# Epoch 84/150
#
# Epoch 84: val_loss improved from 0.46592 to 0.46009, saving model to gru_best.keras
# 2/2 - 0s - 139ms/step - categorical_accuracy: 0.7500 - loss: 0.5027 - val_categorical_accuracy: 0.9000 - val_loss: 0.4601 - learning_rate: 1.0000e-04
# Epoch 85/150
#
# Epoch 85: val_loss improved from 0.46009 to 0.45317, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.7500 - loss: 0.5194 - val_categorical_accuracy: 0.9000 - val_loss: 0.4532 - learning_rate: 1.0000e-04
# Epoch 86/150
#
# Epoch 86: val_loss improved from 0.45317 to 0.44435, saving model to gru_best.keras
# 2/2 - 0s - 136ms/step - categorical_accuracy: 0.8250 - loss: 0.4389 - val_categorical_accuracy: 0.9000 - val_loss: 0.4443 - learning_rate: 1.0000e-04
# Epoch 87/150
#
# Epoch 87: val_loss improved from 0.44435 to 0.43555, saving model to gru_best.keras
# 2/2 - 0s - 136ms/step - categorical_accuracy: 0.7500 - loss: 0.6216 - val_categorical_accuracy: 0.9000 - val_loss: 0.4356 - learning_rate: 1.0000e-04
# Epoch 88/150
#
# Epoch 88: val_loss improved from 0.43555 to 0.42555, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.7500 - loss: 0.6027 - val_categorical_accuracy: 0.9000 - val_loss: 0.4255 - learning_rate: 1.0000e-04
# Epoch 89/150
#
# Epoch 89: val_loss improved from 0.42555 to 0.41608, saving model to gru_best.keras
# 2/2 - 0s - 129ms/step - categorical_accuracy: 0.7250 - loss: 0.8862 - val_categorical_accuracy: 0.9000 - val_loss: 0.4161 - learning_rate: 1.0000e-04
# Epoch 90/150
#
# Epoch 90: val_loss improved from 0.41608 to 0.40444, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.7750 - loss: 0.5183 - val_categorical_accuracy: 0.9000 - val_loss: 0.4044 - learning_rate: 1.0000e-04
# Epoch 91/150
#
# Epoch 91: val_loss improved from 0.40444 to 0.39275, saving model to gru_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.8000 - loss: 0.4536 - val_categorical_accuracy: 0.9000 - val_loss: 0.3928 - learning_rate: 1.0000e-04
# Epoch 92/150
#
# Epoch 92: val_loss improved from 0.39275 to 0.38198, saving model to gru_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.8500 - loss: 0.5512 - val_categorical_accuracy: 0.9000 - val_loss: 0.3820 - learning_rate: 1.0000e-04
# Epoch 93/150
#
# Epoch 93: val_loss improved from 0.38198 to 0.36884, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.8750 - loss: 0.3906 - val_categorical_accuracy: 0.9000 - val_loss: 0.3688 - learning_rate: 1.0000e-04
# Epoch 94/150
#
# Epoch 94: val_loss improved from 0.36884 to 0.35545, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.8000 - loss: 0.5519 - val_categorical_accuracy: 0.9000 - val_loss: 0.3554 - learning_rate: 1.0000e-04
# Epoch 95/150
#
# Epoch 95: val_loss improved from 0.35545 to 0.34417, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.9250 - loss: 0.3497 - val_categorical_accuracy: 0.9000 - val_loss: 0.3442 - learning_rate: 1.0000e-04
# Epoch 96/150
#
# Epoch 96: val_loss improved from 0.34417 to 0.32994, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.8500 - loss: 0.3693 - val_categorical_accuracy: 0.9000 - val_loss: 0.3299 - learning_rate: 1.0000e-04
# Epoch 97/150
#
# Epoch 97: val_loss improved from 0.32994 to 0.31414, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.8750 - loss: 0.3954 - val_categorical_accuracy: 0.9000 - val_loss: 0.3141 - learning_rate: 1.0000e-04
# Epoch 98/150
#
# Epoch 98: val_loss improved from 0.31414 to 0.30438, saving model to gru_best.keras
# 2/2 - 0s - 137ms/step - categorical_accuracy: 0.8500 - loss: 0.5956 - val_categorical_accuracy: 0.9000 - val_loss: 0.3044 - learning_rate: 1.0000e-04
# Epoch 99/150
#
# Epoch 99: val_loss improved from 0.30438 to 0.29748, saving model to gru_best.keras
# 2/2 - 0s - 132ms/step - categorical_accuracy: 0.8750 - loss: 0.3554 - val_categorical_accuracy: 0.9000 - val_loss: 0.2975 - learning_rate: 1.0000e-04
# Epoch 100/150
#
# Epoch 100: val_loss improved from 0.29748 to 0.29199, saving model to gru_best.keras
# 2/2 - 0s - 172ms/step - categorical_accuracy: 0.8250 - loss: 0.6263 - val_categorical_accuracy: 0.9000 - val_loss: 0.2920 - learning_rate: 1.0000e-04
# Epoch 101/150
#
# Epoch 101: val_loss improved from 0.29199 to 0.28908, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.8250 - loss: 0.4599 - val_categorical_accuracy: 0.9000 - val_loss: 0.2891 - learning_rate: 1.0000e-04
# Epoch 102/150
#
# Epoch 102: val_loss improved from 0.28908 to 0.28417, saving model to gru_best.keras
# 2/2 - 0s - 139ms/step - categorical_accuracy: 0.8000 - loss: 0.4247 - val_categorical_accuracy: 0.9000 - val_loss: 0.2842 - learning_rate: 1.0000e-04
# Epoch 103/150
#
# Epoch 103: val_loss improved from 0.28417 to 0.27877, saving model to gru_best.keras
# 2/2 - 0s - 152ms/step - categorical_accuracy: 0.8750 - loss: 0.4364 - val_categorical_accuracy: 0.9000 - val_loss: 0.2788 - learning_rate: 1.0000e-04
# Epoch 104/150
#
# Epoch 104: val_loss improved from 0.27877 to 0.27278, saving model to gru_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.8750 - loss: 0.3405 - val_categorical_accuracy: 0.9000 - val_loss: 0.2728 - learning_rate: 1.0000e-04
# Epoch 105/150
#
# Epoch 105: val_loss improved from 0.27278 to 0.26827, saving model to gru_best.keras
# 2/2 - 0s - 129ms/step - categorical_accuracy: 0.8500 - loss: 0.4631 - val_categorical_accuracy: 0.9000 - val_loss: 0.2683 - learning_rate: 1.0000e-04
# Epoch 106/150
#
# Epoch 106: val_loss improved from 0.26827 to 0.26622, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.8250 - loss: 0.4208 - val_categorical_accuracy: 0.9000 - val_loss: 0.2662 - learning_rate: 1.0000e-04
# Epoch 107/150
#
# Epoch 107: val_loss improved from 0.26622 to 0.26387, saving model to gru_best.keras
# 2/2 - 0s - 127ms/step - categorical_accuracy: 0.9000 - loss: 0.3623 - val_categorical_accuracy: 1.0000 - val_loss: 0.2639 - learning_rate: 1.0000e-04
# Epoch 108/150
#
# Epoch 108: val_loss improved from 0.26387 to 0.26345, saving model to gru_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.8750 - loss: 0.3224 - val_categorical_accuracy: 1.0000 - val_loss: 0.2635 - learning_rate: 1.0000e-04
# Epoch 109/150
#
# Epoch 109: val_loss improved from 0.26345 to 0.26251, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.8500 - loss: 0.4033 - val_categorical_accuracy: 1.0000 - val_loss: 0.2625 - learning_rate: 1.0000e-04
# Epoch 110/150
#
# Epoch 110: val_loss improved from 0.26251 to 0.26189, saving model to gru_best.keras
# 2/2 - 0s - 132ms/step - categorical_accuracy: 0.8250 - loss: 0.5445 - val_categorical_accuracy: 1.0000 - val_loss: 0.2619 - learning_rate: 1.0000e-04
# Epoch 111/150
#
# Epoch 111: val_loss improved from 0.26189 to 0.25814, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.8500 - loss: 0.3435 - val_categorical_accuracy: 1.0000 - val_loss: 0.2581 - learning_rate: 1.0000e-04
# Epoch 112/150
#
# Epoch 112: val_loss improved from 0.25814 to 0.25398, saving model to gru_best.keras
# 2/2 - 0s - 173ms/step - categorical_accuracy: 0.8000 - loss: 0.5003 - val_categorical_accuracy: 1.0000 - val_loss: 0.2540 - learning_rate: 1.0000e-04
# Epoch 113/150
#
# Epoch 113: val_loss improved from 0.25398 to 0.24944, saving model to gru_best.keras
# 2/2 - 0s - 155ms/step - categorical_accuracy: 0.9250 - loss: 0.2766 - val_categorical_accuracy: 1.0000 - val_loss: 0.2494 - learning_rate: 1.0000e-04
# Epoch 114/150
#
# Epoch 114: val_loss improved from 0.24944 to 0.24753, saving model to gru_best.keras
# 2/2 - 0s - 164ms/step - categorical_accuracy: 0.8750 - loss: 0.3614 - val_categorical_accuracy: 1.0000 - val_loss: 0.2475 - learning_rate: 1.0000e-04
# Epoch 115/150
#
# Epoch 115: val_loss improved from 0.24753 to 0.24497, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.7750 - loss: 0.5992 - val_categorical_accuracy: 1.0000 - val_loss: 0.2450 - learning_rate: 1.0000e-04
# Epoch 116/150
#
# Epoch 116: val_loss improved from 0.24497 to 0.23832, saving model to gru_best.keras
# 2/2 - 0s - 137ms/step - categorical_accuracy: 0.7500 - loss: 0.5990 - val_categorical_accuracy: 1.0000 - val_loss: 0.2383 - learning_rate: 1.0000e-04
# Epoch 117/150
#
# Epoch 117: val_loss improved from 0.23832 to 0.23208, saving model to gru_best.keras
# 2/2 - 0s - 158ms/step - categorical_accuracy: 0.7750 - loss: 0.6084 - val_categorical_accuracy: 1.0000 - val_loss: 0.2321 - learning_rate: 1.0000e-04
# Epoch 118/150
#
# Epoch 118: val_loss improved from 0.23208 to 0.22768, saving model to gru_best.keras
# 2/2 - 0s - 182ms/step - categorical_accuracy: 0.9000 - loss: 0.4072 - val_categorical_accuracy: 1.0000 - val_loss: 0.2277 - learning_rate: 1.0000e-04
# Epoch 119/150
#
# Epoch 119: val_loss improved from 0.22768 to 0.22169, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.8750 - loss: 0.3902 - val_categorical_accuracy: 1.0000 - val_loss: 0.2217 - learning_rate: 1.0000e-04
# Epoch 120/150
#
# Epoch 120: val_loss improved from 0.22169 to 0.21813, saving model to gru_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.9000 - loss: 0.3626 - val_categorical_accuracy: 1.0000 - val_loss: 0.2181 - learning_rate: 1.0000e-04
# Epoch 121/150
#
# Epoch 121: val_loss improved from 0.21813 to 0.21488, saving model to gru_best.keras
# 2/2 - 0s - 136ms/step - categorical_accuracy: 0.8000 - loss: 0.4876 - val_categorical_accuracy: 1.0000 - val_loss: 0.2149 - learning_rate: 1.0000e-04
# Epoch 122/150
#
# Epoch 122: val_loss improved from 0.21488 to 0.21216, saving model to gru_best.keras
# 2/2 - 0s - 132ms/step - categorical_accuracy: 0.8500 - loss: 0.3735 - val_categorical_accuracy: 1.0000 - val_loss: 0.2122 - learning_rate: 1.0000e-04
# Epoch 123/150
#
# Epoch 123: val_loss improved from 0.21216 to 0.21006, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.8250 - loss: 0.3288 - val_categorical_accuracy: 1.0000 - val_loss: 0.2101 - learning_rate: 1.0000e-04
# Epoch 124/150
#
# Epoch 124: val_loss improved from 0.21006 to 0.20833, saving model to gru_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.9500 - loss: 0.2787 - val_categorical_accuracy: 1.0000 - val_loss: 0.2083 - learning_rate: 1.0000e-04
# Epoch 125/150
#
# Epoch 125: val_loss improved from 0.20833 to 0.20707, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.8750 - loss: 0.3481 - val_categorical_accuracy: 1.0000 - val_loss: 0.2071 - learning_rate: 1.0000e-04
# Epoch 126/150
#
# Epoch 126: val_loss improved from 0.20707 to 0.20586, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.8500 - loss: 0.3396 - val_categorical_accuracy: 1.0000 - val_loss: 0.2059 - learning_rate: 1.0000e-04
# Epoch 127/150
#
# Epoch 127: val_loss improved from 0.20586 to 0.19950, saving model to gru_best.keras
# 2/2 - 0s - 136ms/step - categorical_accuracy: 0.8500 - loss: 0.3390 - val_categorical_accuracy: 1.0000 - val_loss: 0.1995 - learning_rate: 1.0000e-04
# Epoch 128/150
#
# Epoch 128: val_loss improved from 0.19950 to 0.19149, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.8250 - loss: 0.4257 - val_categorical_accuracy: 1.0000 - val_loss: 0.1915 - learning_rate: 1.0000e-04
# Epoch 129/150
#
# Epoch 129: val_loss improved from 0.19149 to 0.18887, saving model to gru_best.keras
# 2/2 - 0s - 138ms/step - categorical_accuracy: 0.8000 - loss: 0.4190 - val_categorical_accuracy: 1.0000 - val_loss: 0.1889 - learning_rate: 1.0000e-04
# Epoch 130/150
#
# Epoch 130: val_loss did not improve from 0.18887
# 2/2 - 0s - 94ms/step - categorical_accuracy: 0.9000 - loss: 0.3821 - val_categorical_accuracy: 0.9000 - val_loss: 0.1896 - learning_rate: 1.0000e-04
# Epoch 131/150
#
# Epoch 131: val_loss did not improve from 0.18887
# 2/2 - 0s - 100ms/step - categorical_accuracy: 0.8750 - loss: 0.3261 - val_categorical_accuracy: 0.9000 - val_loss: 0.1910 - learning_rate: 1.0000e-04
# Epoch 132/150
#
# Epoch 132: val_loss did not improve from 0.18887
# 2/2 - 0s - 111ms/step - categorical_accuracy: 0.9000 - loss: 0.2976 - val_categorical_accuracy: 0.9000 - val_loss: 0.1890 - learning_rate: 1.0000e-04
# Epoch 133/150
#
# Epoch 133: val_loss improved from 0.18887 to 0.18705, saving model to gru_best.keras
# 2/2 - 0s - 130ms/step - categorical_accuracy: 0.8750 - loss: 0.4676 - val_categorical_accuracy: 0.9000 - val_loss: 0.1870 - learning_rate: 1.0000e-04
# Epoch 134/150
#
# Epoch 134: val_loss improved from 0.18705 to 0.18627, saving model to gru_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.8750 - loss: 0.3597 - val_categorical_accuracy: 0.9000 - val_loss: 0.1863 - learning_rate: 1.0000e-04
# Epoch 135/150
#
# Epoch 135: val_loss improved from 0.18627 to 0.18610, saving model to gru_best.keras
# 2/2 - 0s - 134ms/step - categorical_accuracy: 0.8000 - loss: 0.4748 - val_categorical_accuracy: 0.9000 - val_loss: 0.1861 - learning_rate: 1.0000e-04
# Epoch 136/150
#
# Epoch 136: val_loss improved from 0.18610 to 0.18231, saving model to gru_best.keras
# 2/2 - 0s - 171ms/step - categorical_accuracy: 0.8000 - loss: 0.4740 - val_categorical_accuracy: 1.0000 - val_loss: 0.1823 - learning_rate: 1.0000e-04
# Epoch 137/150
#
# Epoch 137: val_loss improved from 0.18231 to 0.17793, saving model to gru_best.keras
# 2/2 - 0s - 140ms/step - categorical_accuracy: 0.8750 - loss: 0.3116 - val_categorical_accuracy: 1.0000 - val_loss: 0.1779 - learning_rate: 1.0000e-04
# Epoch 138/150
#
# Epoch 138: val_loss improved from 0.17793 to 0.17235, saving model to gru_best.keras
# 2/2 - 0s - 132ms/step - categorical_accuracy: 0.8500 - loss: 0.2932 - val_categorical_accuracy: 1.0000 - val_loss: 0.1724 - learning_rate: 1.0000e-04
# Epoch 139/150
#
# Epoch 139: val_loss improved from 0.17235 to 0.17153, saving model to gru_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.9500 - loss: 0.2315 - val_categorical_accuracy: 1.0000 - val_loss: 0.1715 - learning_rate: 1.0000e-04
# Epoch 140/150
#
# Epoch 140: val_loss improved from 0.17153 to 0.16671, saving model to gru_best.keras
# 2/2 - 0s - 133ms/step - categorical_accuracy: 0.8250 - loss: 0.4102 - val_categorical_accuracy: 1.0000 - val_loss: 0.1667 - learning_rate: 1.0000e-04
# Epoch 141/150
#
# Epoch 141: val_loss improved from 0.16671 to 0.16211, saving model to gru_best.keras
# 2/2 - 0s - 138ms/step - categorical_accuracy: 0.8750 - loss: 0.3852 - val_categorical_accuracy: 1.0000 - val_loss: 0.1621 - learning_rate: 1.0000e-04
# Epoch 142/150
#
# Epoch 142: val_loss improved from 0.16211 to 0.16053, saving model to gru_best.keras
# 2/2 - 0s - 143ms/step - categorical_accuracy: 0.8000 - loss: 0.3709 - val_categorical_accuracy: 1.0000 - val_loss: 0.1605 - learning_rate: 1.0000e-04
# Epoch 143/150
#
# Epoch 143: val_loss improved from 0.16053 to 0.15755, saving model to gru_best.keras
# 2/2 - 0s - 132ms/step - categorical_accuracy: 0.7750 - loss: 0.7209 - val_categorical_accuracy: 1.0000 - val_loss: 0.1575 - learning_rate: 1.0000e-04
# Epoch 144/150
#
# Epoch 144: val_loss improved from 0.15755 to 0.15354, saving model to gru_best.keras
# 2/2 - 0s - 141ms/step - categorical_accuracy: 0.9000 - loss: 0.2167 - val_categorical_accuracy: 1.0000 - val_loss: 0.1535 - learning_rate: 1.0000e-04
# Epoch 145/150
#
# Epoch 145: val_loss improved from 0.15354 to 0.14806, saving model to gru_best.keras
# 2/2 - 0s - 138ms/step - categorical_accuracy: 0.9250 - loss: 0.2578 - val_categorical_accuracy: 1.0000 - val_loss: 0.1481 - learning_rate: 1.0000e-04
# Epoch 146/150
#
# Epoch 146: val_loss improved from 0.14806 to 0.14004, saving model to gru_best.keras
# 2/2 - 0s - 137ms/step - categorical_accuracy: 0.8750 - loss: 0.3714 - val_categorical_accuracy: 1.0000 - val_loss: 0.1400 - learning_rate: 1.0000e-04
# Epoch 147/150
#
# Epoch 147: val_loss improved from 0.14004 to 0.13276, saving model to gru_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.9250 - loss: 0.2851 - val_categorical_accuracy: 1.0000 - val_loss: 0.1328 - learning_rate: 1.0000e-04
# Epoch 148/150
#
# Epoch 148: val_loss improved from 0.13276 to 0.12479, saving model to gru_best.keras
# 2/2 - 0s - 152ms/step - categorical_accuracy: 0.8750 - loss: 0.3950 - val_categorical_accuracy: 1.0000 - val_loss: 0.1248 - learning_rate: 1.0000e-04
# Epoch 149/150
#
# Epoch 149: val_loss improved from 0.12479 to 0.11474, saving model to gru_best.keras
# 2/2 - 0s - 137ms/step - categorical_accuracy: 0.8750 - loss: 0.2500 - val_categorical_accuracy: 1.0000 - val_loss: 0.1147 - learning_rate: 1.0000e-04
# Epoch 150/150
#
# Epoch 150: val_loss improved from 0.11474 to 0.11471, saving model to gru_best.keras
# 2/2 - 0s - 140ms/step - categorical_accuracy: 0.9250 - loss: 0.2043 - val_categorical_accuracy: 1.0000 - val_loss: 0.1147 - learning_rate: 1.0000e-04

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, Dropout, GlobalAveragePooling1D, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler

'''# Misal X_train, X_val, y_train, y_val sudah ada

# Contoh: ambil shape dari X_train
sequence_length = X_train.shape[1]  # 30
feature_size = X_train.shape[2]     # 34

# Normalisasi fitur secara per fitur (feature-wise) untuk setiap timestep
scaler = StandardScaler()

# Flatten data agar bisa di-scaler, lalu reshape kembali
X_train_flat = X_train.reshape(-1, feature_size)
X_train_scaled = scaler.fit_transform(X_train_flat).reshape(-1, sequence_length, feature_size)

X_val_flat = X_val.reshape(-1, feature_size)
X_val_scaled = scaler.transform(X_val_flat).reshape(-1, sequence_length, feature_size)

# Pastikan actions adalah list label yang sesuai dengan jumlah kelas
num_classes = len(actions)  # misal actions = ['walking', 'running', 'jumping', ...]'''

# Definisi model 1D CNN
model_cnn = Sequential([
    Conv1D(256, kernel_size=9, dilation_rate=2, activation='relu', input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2]), padding='same'),
    BatchNormalization(), 
    Dropout(0.4),

    Conv1D(256, kernel_size=5, activation='relu', padding='same'),
    BatchNormalization(), 
    Dropout(0.4),

    GlobalAveragePooling1D(),
    Dense(128, activation='relu'),
    BatchNormalization(), 
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# Compile model
model_cnn.compile(optimizer=Adam(1e-4),
                  loss='categorical_crossentropy',
                  metrics=['categorical_accuracy'])

# Callbacks untuk early stopping, checkpoint, dan learning rate scheduler
callbacks_cnn = [
    EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss', verbose=1),
    ModelCheckpoint('cnn_best.keras', monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(patience=5, factor=0.5, verbose=1)
]

# Training model
history_cnn = model_cnn.fit(
    X_train_scaled, y_train,
    epochs=150,
    batch_size=32,
    validation_data=(X_val_scaled, y_val),
    callbacks=callbacks_cnn,
    verbose=2
)
# Out:
# c:\Users\Nabila\miniconda3\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/150
#
# Epoch 1: val_loss improved from inf to 1.61576, saving model to cnn_best.keras
# 2/2 - 5s - 3s/step - categorical_accuracy: 0.1000 - loss: 3.2485 - val_categorical_accuracy: 0.2000 - val_loss: 1.6158 - learning_rate: 1.0000e-04
# Epoch 2/150
#
# Epoch 2: val_loss improved from 1.61576 to 1.51752, saving model to cnn_best.keras
# 2/2 - 0s - 168ms/step - categorical_accuracy: 0.2250 - loss: 2.3253 - val_categorical_accuracy: 0.2000 - val_loss: 1.5175 - learning_rate: 1.0000e-04
# Epoch 3/150
#
# Epoch 3: val_loss improved from 1.51752 to 1.43424, saving model to cnn_best.keras
# 2/2 - 0s - 211ms/step - categorical_accuracy: 0.4000 - loss: 1.6950 - val_categorical_accuracy: 0.2000 - val_loss: 1.4342 - learning_rate: 1.0000e-04
# Epoch 4/150
#
# Epoch 4: val_loss improved from 1.43424 to 1.37013, saving model to cnn_best.keras
# 2/2 - 0s - 232ms/step - categorical_accuracy: 0.5750 - loss: 1.2808 - val_categorical_accuracy: 0.3000 - val_loss: 1.3701 - learning_rate: 1.0000e-04
# Epoch 5/150
#
# Epoch 5: val_loss improved from 1.37013 to 1.31762, saving model to cnn_best.keras
# 2/2 - 0s - 136ms/step - categorical_accuracy: 0.5250 - loss: 1.1874 - val_categorical_accuracy: 0.6000 - val_loss: 1.3176 - learning_rate: 1.0000e-04
# Epoch 6/150
#
# Epoch 6: val_loss improved from 1.31762 to 1.26731, saving model to cnn_best.keras
# 2/2 - 0s - 148ms/step - categorical_accuracy: 0.6500 - loss: 1.0210 - val_categorical_accuracy: 0.6000 - val_loss: 1.2673 - learning_rate: 1.0000e-04
# Epoch 7/150
#
# Epoch 7: val_loss improved from 1.26731 to 1.21759, saving model to cnn_best.keras
# 2/2 - 0s - 132ms/step - categorical_accuracy: 0.6000 - loss: 1.0699 - val_categorical_accuracy: 0.6000 - val_loss: 1.2176 - learning_rate: 1.0000e-04
# Epoch 8/150
#
# Epoch 8: val_loss improved from 1.21759 to 1.16996, saving model to cnn_best.keras
# 2/2 - 0s - 144ms/step - categorical_accuracy: 0.6250 - loss: 0.8489 - val_categorical_accuracy: 0.6000 - val_loss: 1.1700 - learning_rate: 1.0000e-04
# Epoch 9/150
#
# Epoch 9: val_loss improved from 1.16996 to 1.12803, saving model to cnn_best.keras
# 2/2 - 0s - 128ms/step - categorical_accuracy: 0.7750 - loss: 0.6704 - val_categorical_accuracy: 0.6000 - val_loss: 1.1280 - learning_rate: 1.0000e-04
# Epoch 10/150
#
# Epoch 10: val_loss improved from 1.12803 to 1.09080, saving model to cnn_best.keras
# 2/2 - 0s - 149ms/step - categorical_accuracy: 0.7250 - loss: 0.7465 - val_categorical_accuracy: 0.6000 - val_loss: 1.0908 - learning_rate: 1.0000e-04
# Epoch 11/150
#
# Epoch 11: val_loss improved from 1.09080 to 1.05901, saving model to cnn_best.keras
# 2/2 - 0s - 202ms/step - categorical_accuracy: 0.8000 - loss: 0.4789 - val_categorical_accuracy: 0.6000 - val_loss: 1.0590 - learning_rate: 1.0000e-04
# Epoch 12/150
#
# Epoch 12: val_loss improved from 1.05901 to 1.02799, saving model to cnn_best.keras
# 2/2 - 1s - 317ms/step - categorical_accuracy: 0.7000 - loss: 0.6966 - val_categorical_accuracy: 0.6000 - val_loss: 1.0280 - learning_rate: 1.0000e-04
# Epoch 13/150
#
# Epoch 13: val_loss improved from 1.02799 to 1.00018, saving model to cnn_best.keras
# 2/2 - 0s - 150ms/step - categorical_accuracy: 0.7750 - loss: 0.5195 - val_categorical_accuracy: 0.7000 - val_loss: 1.0002 - learning_rate: 1.0000e-04
# Epoch 14/150
#
# Epoch 14: val_loss improved from 1.00018 to 0.97750, saving model to cnn_best.keras
# 2/2 - 0s - 199ms/step - categorical_accuracy: 0.7750 - loss: 0.5839 - val_categorical_accuracy: 0.7000 - val_loss: 0.9775 - learning_rate: 1.0000e-04
# Epoch 15/150
#
# Epoch 15: val_loss improved from 0.97750 to 0.95608, saving model to cnn_best.keras
# 2/2 - 0s - 146ms/step - categorical_accuracy: 0.8500 - loss: 0.4694 - val_categorical_accuracy: 0.7000 - val_loss: 0.9561 - learning_rate: 1.0000e-04
# Epoch 16/150
#
# Epoch 16: val_loss improved from 0.95608 to 0.93662, saving model to cnn_best.keras
# 2/2 - 0s - 132ms/step - categorical_accuracy: 0.9500 - loss: 0.3567 - val_categorical_accuracy: 0.8000 - val_loss: 0.9366 - learning_rate: 1.0000e-04
# Epoch 17/150
#
# Epoch 17: val_loss improved from 0.93662 to 0.91720, saving model to cnn_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.9000 - loss: 0.4544 - val_categorical_accuracy: 0.8000 - val_loss: 0.9172 - learning_rate: 1.0000e-04
# Epoch 18/150
#
# Epoch 18: val_loss improved from 0.91720 to 0.89656, saving model to cnn_best.keras
# 2/2 - 0s - 163ms/step - categorical_accuracy: 0.9000 - loss: 0.3600 - val_categorical_accuracy: 0.9000 - val_loss: 0.8966 - learning_rate: 1.0000e-04
# Epoch 19/150
#
# Epoch 19: val_loss improved from 0.89656 to 0.87750, saving model to cnn_best.keras
# 2/2 - 0s - 132ms/step - categorical_accuracy: 0.8500 - loss: 0.4025 - val_categorical_accuracy: 0.9000 - val_loss: 0.8775 - learning_rate: 1.0000e-04
# Epoch 20/150
#
# Epoch 20: val_loss improved from 0.87750 to 0.86199, saving model to cnn_best.keras
# 2/2 - 0s - 125ms/step - categorical_accuracy: 0.8500 - loss: 0.4243 - val_categorical_accuracy: 0.9000 - val_loss: 0.8620 - learning_rate: 1.0000e-04
# Epoch 21/150
#
# Epoch 21: val_loss improved from 0.86199 to 0.84904, saving model to cnn_best.keras
# 2/2 - 0s - 128ms/step - categorical_accuracy: 0.8000 - loss: 0.5173 - val_categorical_accuracy: 0.9000 - val_loss: 0.8490 - learning_rate: 1.0000e-04
# Epoch 22/150
#
# Epoch 22: val_loss improved from 0.84904 to 0.83633, saving model to cnn_best.keras
# 2/2 - 0s - 126ms/step - categorical_accuracy: 0.9000 - loss: 0.4215 - val_categorical_accuracy: 0.9000 - val_loss: 0.8363 - learning_rate: 1.0000e-04
# Epoch 23/150
#
# Epoch 23: val_loss improved from 0.83633 to 0.82652, saving model to cnn_best.keras
# 2/2 - 0s - 125ms/step - categorical_accuracy: 0.8750 - loss: 0.4222 - val_categorical_accuracy: 0.9000 - val_loss: 0.8265 - learning_rate: 1.0000e-04
# Epoch 24/150
#
# Epoch 24: val_loss improved from 0.82652 to 0.81661, saving model to cnn_best.keras
# 2/2 - 0s - 125ms/step - categorical_accuracy: 0.8750 - loss: 0.4803 - val_categorical_accuracy: 1.0000 - val_loss: 0.8166 - learning_rate: 1.0000e-04
# Epoch 25/150
#
# Epoch 25: val_loss improved from 0.81661 to 0.80728, saving model to cnn_best.keras
# 2/2 - 0s - 130ms/step - categorical_accuracy: 0.8750 - loss: 0.4075 - val_categorical_accuracy: 1.0000 - val_loss: 0.8073 - learning_rate: 1.0000e-04
# Epoch 26/150
#
# Epoch 26: val_loss improved from 0.80728 to 0.79828, saving model to cnn_best.keras
# 2/2 - 0s - 126ms/step - categorical_accuracy: 0.8500 - loss: 0.4016 - val_categorical_accuracy: 1.0000 - val_loss: 0.7983 - learning_rate: 1.0000e-04
# Epoch 27/150
#
# Epoch 27: val_loss improved from 0.79828 to 0.78819, saving model to cnn_best.keras
# 2/2 - 0s - 128ms/step - categorical_accuracy: 0.9000 - loss: 0.2956 - val_categorical_accuracy: 1.0000 - val_loss: 0.7882 - learning_rate: 1.0000e-04
# Epoch 28/150
#
# Epoch 28: val_loss improved from 0.78819 to 0.77513, saving model to cnn_best.keras
# 2/2 - 0s - 141ms/step - categorical_accuracy: 0.8500 - loss: 0.4236 - val_categorical_accuracy: 1.0000 - val_loss: 0.7751 - learning_rate: 1.0000e-04
# Epoch 29/150
#
# Epoch 29: val_loss improved from 0.77513 to 0.75933, saving model to cnn_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.8500 - loss: 0.3998 - val_categorical_accuracy: 1.0000 - val_loss: 0.7593 - learning_rate: 1.0000e-04
# Epoch 30/150
#
# Epoch 30: val_loss improved from 0.75933 to 0.74561, saving model to cnn_best.keras
# 2/2 - 0s - 184ms/step - categorical_accuracy: 0.8500 - loss: 0.3361 - val_categorical_accuracy: 1.0000 - val_loss: 0.7456 - learning_rate: 1.0000e-04
# Epoch 31/150
#
# Epoch 31: val_loss improved from 0.74561 to 0.73030, saving model to cnn_best.keras
# 2/2 - 0s - 132ms/step - categorical_accuracy: 0.8750 - loss: 0.2946 - val_categorical_accuracy: 1.0000 - val_loss: 0.7303 - learning_rate: 1.0000e-04
# Epoch 32/150
#
# Epoch 32: val_loss improved from 0.73030 to 0.71563, saving model to cnn_best.keras
# 2/2 - 0s - 127ms/step - categorical_accuracy: 0.8000 - loss: 0.4407 - val_categorical_accuracy: 1.0000 - val_loss: 0.7156 - learning_rate: 1.0000e-04
# Epoch 33/150
#
# Epoch 33: val_loss improved from 0.71563 to 0.70392, saving model to cnn_best.keras
# 2/2 - 0s - 127ms/step - categorical_accuracy: 0.8500 - loss: 0.3235 - val_categorical_accuracy: 1.0000 - val_loss: 0.7039 - learning_rate: 1.0000e-04
# Epoch 34/150
#
# Epoch 34: val_loss improved from 0.70392 to 0.69041, saving model to cnn_best.keras
# 2/2 - 0s - 124ms/step - categorical_accuracy: 0.9500 - loss: 0.2253 - val_categorical_accuracy: 1.0000 - val_loss: 0.6904 - learning_rate: 1.0000e-04
# Epoch 35/150
#
# Epoch 35: val_loss improved from 0.69041 to 0.67628, saving model to cnn_best.keras
# 2/2 - 0s - 123ms/step - categorical_accuracy: 0.7250 - loss: 0.4589 - val_categorical_accuracy: 1.0000 - val_loss: 0.6763 - learning_rate: 1.0000e-04
# Epoch 36/150
#
# Epoch 36: val_loss improved from 0.67628 to 0.66288, saving model to cnn_best.keras
# 2/2 - 0s - 122ms/step - categorical_accuracy: 0.9000 - loss: 0.3151 - val_categorical_accuracy: 1.0000 - val_loss: 0.6629 - learning_rate: 1.0000e-04
# Epoch 37/150
#
# Epoch 37: val_loss improved from 0.66288 to 0.65469, saving model to cnn_best.keras
# 2/2 - 0s - 125ms/step - categorical_accuracy: 0.9000 - loss: 0.3245 - val_categorical_accuracy: 1.0000 - val_loss: 0.6547 - learning_rate: 1.0000e-04
# Epoch 38/150
#
# Epoch 38: val_loss improved from 0.65469 to 0.64743, saving model to cnn_best.keras
# 2/2 - 0s - 121ms/step - categorical_accuracy: 0.8750 - loss: 0.2967 - val_categorical_accuracy: 1.0000 - val_loss: 0.6474 - learning_rate: 1.0000e-04
# Epoch 39/150
#
# Epoch 39: val_loss improved from 0.64743 to 0.63950, saving model to cnn_best.keras
# 2/2 - 0s - 125ms/step - categorical_accuracy: 0.8500 - loss: 0.3509 - val_categorical_accuracy: 1.0000 - val_loss: 0.6395 - learning_rate: 1.0000e-04
# Epoch 40/150
#
# Epoch 40: val_loss improved from 0.63950 to 0.63308, saving model to cnn_best.keras
# 2/2 - 0s - 125ms/step - categorical_accuracy: 0.8750 - loss: 0.2694 - val_categorical_accuracy: 1.0000 - val_loss: 0.6331 - learning_rate: 1.0000e-04
# Epoch 41/150
#
# Epoch 41: val_loss improved from 0.63308 to 0.62629, saving model to cnn_best.keras
# 2/2 - 0s - 129ms/step - categorical_accuracy: 0.9500 - loss: 0.1791 - val_categorical_accuracy: 1.0000 - val_loss: 0.6263 - learning_rate: 1.0000e-04
# Epoch 42/150
#
# Epoch 42: val_loss improved from 0.62629 to 0.61952, saving model to cnn_best.keras
# 2/2 - 0s - 128ms/step - categorical_accuracy: 0.9750 - loss: 0.1561 - val_categorical_accuracy: 1.0000 - val_loss: 0.6195 - learning_rate: 1.0000e-04
# Epoch 43/150
#
# Epoch 43: val_loss improved from 0.61952 to 0.61124, saving model to cnn_best.keras
# 2/2 - 0s - 129ms/step - categorical_accuracy: 0.8750 - loss: 0.3129 - val_categorical_accuracy: 1.0000 - val_loss: 0.6112 - learning_rate: 1.0000e-04
# Epoch 44/150
#
# Epoch 44: val_loss improved from 0.61124 to 0.60191, saving model to cnn_best.keras
# 2/2 - 0s - 144ms/step - categorical_accuracy: 0.9000 - loss: 0.2795 - val_categorical_accuracy: 1.0000 - val_loss: 0.6019 - learning_rate: 1.0000e-04
# Epoch 45/150
#
# Epoch 45: val_loss improved from 0.60191 to 0.59213, saving model to cnn_best.keras
# 2/2 - 0s - 129ms/step - categorical_accuracy: 0.9000 - loss: 0.2458 - val_categorical_accuracy: 1.0000 - val_loss: 0.5921 - learning_rate: 1.0000e-04
# Epoch 46/150
#
# Epoch 46: val_loss improved from 0.59213 to 0.58323, saving model to cnn_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.8500 - loss: 0.2814 - val_categorical_accuracy: 1.0000 - val_loss: 0.5832 - learning_rate: 1.0000e-04
# Epoch 47/150
#
# Epoch 47: val_loss improved from 0.58323 to 0.57653, saving model to cnn_best.keras
# 2/2 - 0s - 127ms/step - categorical_accuracy: 0.9250 - loss: 0.1615 - val_categorical_accuracy: 1.0000 - val_loss: 0.5765 - learning_rate: 1.0000e-04
# Epoch 48/150
#
# Epoch 48: val_loss improved from 0.57653 to 0.56940, saving model to cnn_best.keras
# 2/2 - 0s - 184ms/step - categorical_accuracy: 0.9250 - loss: 0.2813 - val_categorical_accuracy: 1.0000 - val_loss: 0.5694 - learning_rate: 1.0000e-04
# Epoch 49/150
#
# Epoch 49: val_loss improved from 0.56940 to 0.56164, saving model to cnn_best.keras
# 2/2 - 0s - 125ms/step - categorical_accuracy: 0.9500 - loss: 0.3901 - val_categorical_accuracy: 1.0000 - val_loss: 0.5616 - learning_rate: 1.0000e-04
# Epoch 50/150
#
# Epoch 50: val_loss improved from 0.56164 to 0.55255, saving model to cnn_best.keras
# 2/2 - 0s - 157ms/step - categorical_accuracy: 0.8750 - loss: 0.3033 - val_categorical_accuracy: 1.0000 - val_loss: 0.5526 - learning_rate: 1.0000e-04
# Epoch 51/150
#
# Epoch 51: val_loss improved from 0.55255 to 0.54233, saving model to cnn_best.keras
# 2/2 - 0s - 128ms/step - categorical_accuracy: 0.9000 - loss: 0.3044 - val_categorical_accuracy: 1.0000 - val_loss: 0.5423 - learning_rate: 1.0000e-04
# Epoch 52/150
#
# Epoch 52: val_loss improved from 0.54233 to 0.53113, saving model to cnn_best.keras
# 2/2 - 0s - 125ms/step - categorical_accuracy: 0.9500 - loss: 0.2053 - val_categorical_accuracy: 1.0000 - val_loss: 0.5311 - learning_rate: 1.0000e-04
# Epoch 53/150
#
# Epoch 53: val_loss improved from 0.53113 to 0.51937, saving model to cnn_best.keras
# 2/2 - 0s - 126ms/step - categorical_accuracy: 0.9250 - loss: 0.1906 - val_categorical_accuracy: 1.0000 - val_loss: 0.5194 - learning_rate: 1.0000e-04
# Epoch 54/150
#
# Epoch 54: val_loss improved from 0.51937 to 0.50689, saving model to cnn_best.keras
# 2/2 - 0s - 126ms/step - categorical_accuracy: 0.8750 - loss: 0.3030 - val_categorical_accuracy: 1.0000 - val_loss: 0.5069 - learning_rate: 1.0000e-04
# Epoch 55/150
#
# Epoch 55: val_loss improved from 0.50689 to 0.49591, saving model to cnn_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.9250 - loss: 0.2152 - val_categorical_accuracy: 1.0000 - val_loss: 0.4959 - learning_rate: 1.0000e-04
# Epoch 56/150
#
# Epoch 56: val_loss improved from 0.49591 to 0.48634, saving model to cnn_best.keras
# 2/2 - 0s - 129ms/step - categorical_accuracy: 0.8500 - loss: 0.3679 - val_categorical_accuracy: 1.0000 - val_loss: 0.4863 - learning_rate: 1.0000e-04
# Epoch 57/150
#
# Epoch 57: val_loss improved from 0.48634 to 0.48184, saving model to cnn_best.keras
# 2/2 - 0s - 125ms/step - categorical_accuracy: 0.9000 - loss: 0.2353 - val_categorical_accuracy: 1.0000 - val_loss: 0.4818 - learning_rate: 1.0000e-04
# Epoch 58/150
#
# Epoch 58: val_loss improved from 0.48184 to 0.47535, saving model to cnn_best.keras
# 2/2 - 0s - 135ms/step - categorical_accuracy: 0.9250 - loss: 0.2212 - val_categorical_accuracy: 1.0000 - val_loss: 0.4754 - learning_rate: 1.0000e-04
# Epoch 59/150
#
# Epoch 59: val_loss improved from 0.47535 to 0.46743, saving model to cnn_best.keras
# 2/2 - 0s - 125ms/step - categorical_accuracy: 0.9000 - loss: 0.3246 - val_categorical_accuracy: 1.0000 - val_loss: 0.4674 - learning_rate: 1.0000e-04
# Epoch 60/150
#
# Epoch 60: val_loss improved from 0.46743 to 0.45335, saving model to cnn_best.keras
# 2/2 - 0s - 146ms/step - categorical_accuracy: 0.8750 - loss: 0.3217 - val_categorical_accuracy: 1.0000 - val_loss: 0.4533 - learning_rate: 1.0000e-04
# Epoch 61/150
#
# Epoch 61: val_loss improved from 0.45335 to 0.43899, saving model to cnn_best.keras
# 2/2 - 0s - 147ms/step - categorical_accuracy: 0.9750 - loss: 0.1804 - val_categorical_accuracy: 1.0000 - val_loss: 0.4390 - learning_rate: 1.0000e-04
# Epoch 62/150
#
# Epoch 62: val_loss improved from 0.43899 to 0.42689, saving model to cnn_best.keras
# 2/2 - 0s - 131ms/step - categorical_accuracy: 0.9750 - loss: 0.1754 - val_categorical_accuracy: 1.0000 - val_loss: 0.4269 - learning_rate: 1.0000e-04
# Epoch 63/150
#
# Epoch 63: val_loss improved from 0.42689 to 0.41759, saving model to cnn_best.keras
# 2/2 - 0s - 126ms/step - categorical_accuracy: 0.9000 - loss: 0.2460 - val_categorical_accuracy: 1.0000 - val_loss: 0.4176 - learning_rate: 1.0000e-04
# Epoch 64/150
#
# Epoch 64: val_loss improved from 0.41759 to 0.41190, saving model to cnn_best.keras
# 2/2 - 0s - 122ms/step - categorical_accuracy: 0.9500 - loss: 0.1543 - val_categorical_accuracy: 1.0000 - val_loss: 0.4119 - learning_rate: 1.0000e-04
# Epoch 65/150
#
# Epoch 65: val_loss improved from 0.41190 to 0.40822, saving model to cnn_best.keras
# 2/2 - 0s - 126ms/step - categorical_accuracy: 0.8500 - loss: 0.2987 - val_categorical_accuracy: 1.0000 - val_loss: 0.4082 - learning_rate: 1.0000e-04
# Epoch 66/150
#
# Epoch 66: val_loss improved from 0.40822 to 0.40708, saving model to cnn_best.keras
# 2/2 - 0s - 125ms/step - categorical_accuracy: 0.8750 - loss: 0.2892 - val_categorical_accuracy: 1.0000 - val_loss: 0.4071 - learning_rate: 1.0000e-04
# Epoch 67/150
#
# Epoch 67: val_loss did not improve from 0.40708
# 2/2 - 0s - 86ms/step - categorical_accuracy: 0.9000 - loss: 0.1914 - val_categorical_accuracy: 1.0000 - val_loss: 0.4105 - learning_rate: 1.0000e-04
# Epoch 68/150
#
# Epoch 68: val_loss did not improve from 0.40708
# 2/2 - 0s - 83ms/step - categorical_accuracy: 0.9250 - loss: 0.1944 - val_categorical_accuracy: 1.0000 - val_loss: 0.4148 - learning_rate: 1.0000e-04
# Epoch 69/150
#
# Epoch 69: val_loss did not improve from 0.40708
# 2/2 - 0s - 84ms/step - categorical_accuracy: 0.9000 - loss: 0.2415 - val_categorical_accuracy: 1.0000 - val_loss: 0.4246 - learning_rate: 1.0000e-04
# Epoch 70/150
#
# Epoch 70: val_loss did not improve from 0.40708
# 2/2 - 0s - 82ms/step - categorical_accuracy: 0.8750 - loss: 0.3286 - val_categorical_accuracy: 0.9000 - val_loss: 0.4303 - learning_rate: 1.0000e-04
# Epoch 71/150
#
# Epoch 71: val_loss did not improve from 0.40708
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2/2 - 0s - 89ms/step - categorical_accuracy: 0.9000 - loss: 0.2091 - val_categorical_accuracy: 0.9000 - val_loss: 0.4254 - learning_rate: 1.0000e-04
# Epoch 72/150
#
# Epoch 72: val_loss did not improve from 0.40708
# 2/2 - 0s - 87ms/step - categorical_accuracy: 0.8750 - loss: 0.2970 - val_categorical_accuracy: 0.9000 - val_loss: 0.4195 - learning_rate: 5.0000e-05
# Epoch 73/150
#
# Epoch 73: val_loss did not improve from 0.40708
# 2/2 - 0s - 82ms/step - categorical_accuracy: 0.8750 - loss: 0.2776 - val_categorical_accuracy: 0.9000 - val_loss: 0.4133 - learning_rate: 5.0000e-05
# Epoch 74/150
#
# Epoch 74: val_loss improved from 0.40708 to 0.40621, saving model to cnn_best.keras
# 2/2 - 0s - 122ms/step - categorical_accuracy: 0.9750 - loss: 0.1768 - val_categorical_accuracy: 0.9000 - val_loss: 0.4062 - learning_rate: 5.0000e-05
# Epoch 75/150
#
# Epoch 75: val_loss improved from 0.40621 to 0.39688, saving model to cnn_best.keras
# 2/2 - 0s - 124ms/step - categorical_accuracy: 0.9250 - loss: 0.2221 - val_categorical_accuracy: 0.9000 - val_loss: 0.3969 - learning_rate: 5.0000e-05
# Epoch 76/150
#
# Epoch 76: val_loss improved from 0.39688 to 0.38788, saving model to cnn_best.keras
# 2/2 - 0s - 189ms/step - categorical_accuracy: 1.0000 - loss: 0.0794 - val_categorical_accuracy: 0.9000 - val_loss: 0.3879 - learning_rate: 5.0000e-05
# Epoch 77/150
#
# Epoch 77: val_loss improved from 0.38788 to 0.37779, saving model to cnn_best.keras
# 2/2 - 0s - 179ms/step - categorical_accuracy: 0.9250 - loss: 0.2613 - val_categorical_accuracy: 1.0000 - val_loss: 0.3778 - learning_rate: 5.0000e-05
# Epoch 78/150
#
# Epoch 78: val_loss improved from 0.37779 to 0.36503, saving model to cnn_best.keras
# 2/2 - 0s - 174ms/step - categorical_accuracy: 0.9000 - loss: 0.2908 - val_categorical_accuracy: 1.0000 - val_loss: 0.3650 - learning_rate: 5.0000e-05
# Epoch 79/150
#
# Epoch 79: val_loss improved from 0.36503 to 0.35350, saving model to cnn_best.keras
# 2/2 - 0s - 183ms/step - categorical_accuracy: 0.9000 - loss: 0.2674 - val_categorical_accuracy: 1.0000 - val_loss: 0.3535 - learning_rate: 5.0000e-05
# Epoch 80/150
#
# Epoch 80: val_loss improved from 0.35350 to 0.34080, saving model to cnn_best.keras
# 2/2 - 0s - 123ms/step - categorical_accuracy: 0.9250 - loss: 0.1463 - val_categorical_accuracy: 1.0000 - val_loss: 0.3408 - learning_rate: 5.0000e-05
# Epoch 81/150
#
# Epoch 81: val_loss improved from 0.34080 to 0.32986, saving model to cnn_best.keras
# 2/2 - 0s - 129ms/step - categorical_accuracy: 0.9750 - loss: 0.1398 - val_categorical_accuracy: 1.0000 - val_loss: 0.3299 - learning_rate: 5.0000e-05
# Epoch 82/150
#
# Epoch 82: val_loss improved from 0.32986 to 0.31822, saving model to cnn_best.keras
# 2/2 - 0s - 126ms/step - categorical_accuracy: 0.9000 - loss: 0.2997 - val_categorical_accuracy: 1.0000 - val_loss: 0.3182 - learning_rate: 5.0000e-05
# Epoch 83/150
#
# Epoch 83: val_loss improved from 0.31822 to 0.30947, saving model to cnn_best.keras
# 2/2 - 0s - 123ms/step - categorical_accuracy: 0.9500 - loss: 0.1969 - val_categorical_accuracy: 1.0000 - val_loss: 0.3095 - learning_rate: 5.0000e-05
# Epoch 84/150
#
# Epoch 84: val_loss improved from 0.30947 to 0.30088, saving model to cnn_best.keras
# 2/2 - 0s - 124ms/step - categorical_accuracy: 0.9250 - loss: 0.1584 - val_categorical_accuracy: 1.0000 - val_loss: 0.3009 - learning_rate: 5.0000e-05
# Epoch 85/150
#
# Epoch 85: val_loss improved from 0.30088 to 0.29397, saving model to cnn_best.keras
# 2/2 - 0s - 125ms/step - categorical_accuracy: 0.9000 - loss: 0.1968 - val_categorical_accuracy: 1.0000 - val_loss: 0.2940 - learning_rate: 5.0000e-05
# Epoch 86/150
#
# Epoch 86: val_loss improved from 0.29397 to 0.28768, saving model to cnn_best.keras
# 2/2 - 0s - 126ms/step - categorical_accuracy: 0.9500 - loss: 0.1731 - val_categorical_accuracy: 1.0000 - val_loss: 0.2877 - learning_rate: 5.0000e-05
# Epoch 87/150
#
# Epoch 87: val_loss improved from 0.28768 to 0.28293, saving model to cnn_best.keras
# 2/2 - 0s - 127ms/step - categorical_accuracy: 0.9250 - loss: 0.2598 - val_categorical_accuracy: 1.0000 - val_loss: 0.2829 - learning_rate: 5.0000e-05
# Epoch 88/150
#
# Epoch 88: val_loss did not improve from 0.28293
# 2/2 - 0s - 117ms/step - categorical_accuracy: 0.9250 - loss: 0.2287 - val_categorical_accuracy: 1.0000 - val_loss: 0.2831 - learning_rate: 5.0000e-05
# Epoch 89/150
#
# Epoch 89: val_loss did not improve from 0.28293
# 2/2 - 0s - 107ms/step - categorical_accuracy: 0.9500 - loss: 0.1994 - val_categorical_accuracy: 1.0000 - val_loss: 0.2895 - learning_rate: 5.0000e-05
# Epoch 90/150
#
# Epoch 90: val_loss did not improve from 0.28293
# 2/2 - 0s - 96ms/step - categorical_accuracy: 0.8750 - loss: 0.3941 - val_categorical_accuracy: 1.0000 - val_loss: 0.2972 - learning_rate: 5.0000e-05
# Epoch 91/150
#
# Epoch 91: val_loss did not improve from 0.28293
# 2/2 - 0s - 92ms/step - categorical_accuracy: 0.8750 - loss: 0.3870 - val_categorical_accuracy: 1.0000 - val_loss: 0.3020 - learning_rate: 5.0000e-05
# Epoch 92/150
#
# Epoch 92: val_loss did not improve from 0.28293
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 2/2 - 0s - 85ms/step - categorical_accuracy: 0.9500 - loss: 0.2032 - val_categorical_accuracy: 1.0000 - val_loss: 0.3101 - learning_rate: 5.0000e-05
# Epoch 93/150
#
# Epoch 93: val_loss did not improve from 0.28293
# 2/2 - 0s - 85ms/step - categorical_accuracy: 1.0000 - loss: 0.0966 - val_categorical_accuracy: 1.0000 - val_loss: 0.3125 - learning_rate: 2.5000e-05
# Epoch 94/150
#
# Epoch 94: val_loss did not improve from 0.28293
# 2/2 - 0s - 110ms/step - categorical_accuracy: 0.9500 - loss: 0.1548 - val_categorical_accuracy: 0.9000 - val_loss: 0.3133 - learning_rate: 2.5000e-05
# Epoch 95/150
#
# Epoch 95: val_loss did not improve from 0.28293
# 2/2 - 0s - 198ms/step - categorical_accuracy: 0.9500 - loss: 0.1699 - val_categorical_accuracy: 0.9000 - val_loss: 0.3122 - learning_rate: 2.5000e-05
# Epoch 96/150
#
# Epoch 96: val_loss did not improve from 0.28293
# 2/2 - 0s - 142ms/step - categorical_accuracy: 0.9500 - loss: 0.1588 - val_categorical_accuracy: 0.9000 - val_loss: 0.3120 - learning_rate: 2.5000e-05
# Epoch 97/150
#
# Epoch 97: val_loss did not improve from 0.28293
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 2/2 - 0s - 92ms/step - categorical_accuracy: 0.9250 - loss: 0.1673 - val_categorical_accuracy: 0.9000 - val_loss: 0.3098 - learning_rate: 2.5000e-05
# Epoch 97: early stopping
# Restoring model weights from the end of the best epoch: 87.

# %% [markdown]
# # Grafik

# %%
plt.figure()
plt.plot(history_lstm.history['categorical_accuracy'], label='LSTM')
plt.plot(history_gru.history['categorical_accuracy'], label='GRU')
plt.plot(history_cnn.history['categorical_accuracy'], label='CNN')
plt.legend() 
plt.title("Train Accuracy")

plt.figure()
plt.plot(history_lstm.history['val_categorical_accuracy'], label='LSTM')
plt.plot(history_gru.history['val_categorical_accuracy'], label='GRU')
plt.plot(history_cnn.history['val_categorical_accuracy'], label='CNN')
plt.legend()
plt.title("Val Accuracy")

plt.figure()
plt.plot(history_lstm.history['loss'], label='LSTM')
plt.plot(history_gru.history['loss'], label='GRU')
plt.plot(history_cnn.history['loss'], label='CNN')
plt.legend()
plt.title("Train Loss")
plt.show()

plt.figure()
plt.plot(history_lstm.history['val_loss'], label='LSTM')
plt.plot(history_gru.history['val_loss'], label='GRU')
plt.plot(history_cnn.history['val_loss'], label='CNN')
plt.legend()
plt.title("Val Loss")
plt.show()

# %% [markdown]
# ## **b. Evaluasi Model**

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report
from sklearn.model_selection import GroupShuffleSplit
from tensorflow.keras.models import load_model
# =========================
# 2. Fungsi Evaluasi di Validation Set
# =========================
def eval_val(model):
    y_prob = model.predict(X_val, verbose=0)
    y_pred = np.argmax(y_prob, axis=1)
    y_true = np.argmax(y_val, axis=1)
    acc = accuracy_score(y_true, y_pred)
    prec, rec, f1, _ = precision_recall_fscore_support(
        y_true, y_pred, average='macro', zero_division=0)
    return acc, prec, rec, f1, y_true, y_pred

# =========================
# 3. Evaluasi Semua Model
# =========================
models = {
    'LSTM': 'lstm_best.keras',
    'GRU': 'gru_best.keras',
    'CNN': 'cnn_best.keras'
}

scores = []

for name, fpath in models.items():
    m = load_model(fpath)
    acc, prec, rec, f1, _, _ = eval_val(m)
    scores.append(dict(model=name, acc=acc, prec=prec, rec=rec, f1=f1))

print('\n=== Validation Performance ===')
perf = pd.DataFrame(scores).set_index('model').round(3)
display(perf)

# =========================
# 4. Model Terbaik + Confusion Matrix
# =========================
best = perf['f1'].idxmax()
best_model = load_model(models[best])
acc, prec, rec, f1, y_true, y_pred = eval_val(best_model)

cm = confusion_matrix(y_true, y_pred, labels=range(len(actions)))
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=actions, yticklabels=actions, cmap='Blues')
plt.title(f'Confusion Matrix – {best} (Validation)')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

print(classification_report(y_true, y_pred, target_names=actions, zero_division=0))
# Out:
# === Validation Performance ===
#        acc   prec  rec     f1
# model
# LSTM   0.8  0.667  0.8  0.720
# GRU    1.0  1.000  1.0  1.000
# CNN    0.6  0.667  0.6  0.567
#                         precision    recall  f1-score   support
#
#         Angkat Pinggul       1.00      1.00      1.00         2
#          Angkat Tangan       1.00      1.00      1.00         2
#            Lutut Turun       1.00      1.00      1.00         2
# Naikan Kepalan Kedepan       1.00      1.00      1.00         2
#             Rentangkan       1.00      1.00      1.00         2
#
#               accuracy                           1.00        10
#              macro avg       1.00      1.00      1.00        10
#           weighted avg       1.00      1.00      1.00        10

# %%
import shutil

# Kompres folder 'keypoint' jadi 'keypoint.zip' di direktori kerja
shutil.make_archive('/kaggle/working/keypoints', 'zip', '/kaggle/working/keypoints')
# Out:
# '/kaggle/working/keypoints.zip'

# %% [markdown]
# # **6. Inferensi Model**

# %% [markdown]
# ## **a. Inferensi Klasifikasi Gerakan**

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from tensorflow.keras.models import load_model
from collections import deque

# ------------ Parameter ---------------
SEQ_LEN       = 30
DETECT_THRESH = 0.6
LABELS = np.array(['Angkat Pinggul', 'Kaki Kebelakang', 'Lutut Turun', 'Naikan Kepalan Kedepan', 'Rentangkan'])

# ------------ Load model ---------------
pose_model = YOLO('yolov8n-pose.pt')         # YOLOv8 pose model
lstm_model = load_model('gru_best.keras')  # Model LSTM hasil training

# ------------ Buffer sequence -----------
buf = deque(maxlen=SEQ_LEN)

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Inference YOLOv8 Pose
    results = pose_model(frame)[0]

    # Ekstrak keypoints orang pertama jika ada
    if results.keypoints is not None and len(results.keypoints) > 0:
        # Ambil data keypoints dari atribut data dan ubah ke numpy array
        keypoints = results.keypoints.data.cpu().numpy()[0]  # (17, 3)

        h, w, _ = frame.shape
        pose_vec = []
        for x, y, c in keypoints:
            pose_vec.extend([x / w, y / h, c])
        pose_vec = np.array(pose_vec, dtype='float32')
    else:
        pose_vec = np.zeros(17 * 3, dtype='float32')  # kalau gak ada pose

    buf.append(pose_vec)

    # Jika buffer sequence sudah penuh, infer LSTM
    if len(buf) == SEQ_LEN:
        seq_input = np.expand_dims(np.array(buf), axis=0)  # (1, SEQ_LEN, 51)
        probs = lstm_model.predict(seq_input, verbose=0)[0]  # output probabilitas per kelas
        idx_pred = np.argmax(probs)
        conf = probs[idx_pred]
        pred_label = LABELS[idx_pred]

        # Tampilkan prediksi di frame
        text = f"Pose: {pred_label} ({conf*100:.1f}%)"
        cv2.putText(frame, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX,
                    1, (0, 255, 0) if conf > DETECT_THRESH else (0, 0, 255), 2)

    # Tampilkan hasil keypoints
    annotated_frame = results.plot()
    cv2.imshow('YOLOv8 Pose + LSTM', annotated_frame)

    if cv2.waitKey(1) & 0xFF == 27:  # ESC keluar
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## **b. Inferensi Lanjutan**

# %%
import cv2
import numpy as np
import time
from collections import deque
from ultralytics import YOLO
from tensorflow.keras.models import load_model

# ---------- LABEL TETAP (sesuai training) ----------
LABELS = np.array(['Angkat Pinggul',
                   'Angkat Tangan',
                   'Lutut Turun',
                   'Naikan Kepalan Kedepan',
                   'Rentangkan'])

label2idx = {l: i for i, l in enumerate(LABELS)}

# ---------- URUTAN LATIHAN (bebas diubah) ----------
WORKFLOW = np.array(['Angkat Tangan','Naikan Kepalan Kedepan', 'Rentangkan'])

# ---------- PARAMETER LAIN ----------
SEQ_LEN = 30
DETECT_THRESH = 0.60
STABLE_FRAMES = 15
EXER_TIME = 30
POPUP_TIME = 10
MODEL_PATH = 'lstm_best.keras'
FONT = cv2.FONT_HERSHEY_SIMPLEX

# ---------- MODEL & YOLO ----------
model = load_model(MODEL_PATH)
yolo_model = YOLO('yolov8n-pose.pt')  # Gunakan model YOLOv8 Pose

# ---------- Fungsi Ekstraksi Keypoints ----------
def extract_keypoints(results):
    keypoints = results.keypoints
    if keypoints is not None:
        # Ambil keypoints dalam format [x, y, confidence]
        kpts = keypoints.xy[0].cpu().numpy().flatten()
    else:
        kpts = np.zeros(17 * 3)  # 17 keypoints dengan [x, y, conf]
    return kpts.astype('float32')

# ------- Inisialisasi sebelum while ----------
buf = deque(maxlen=SEQ_LEN)
state = 'Belum Bergerak'
idx_act = 0
steady_ctr = 0
t_ex_start = time.time()

popup_phase = None  # None | 'result' | 'prep'
popup_start = None
score = {w: None for w in WORKFLOW}
last_pred, last_conf = '-', 0.0

cap = cv2.VideoCapture(0)
while cap.isOpened() and idx_act < len(WORKFLOW):
    ok, frame = cap.read()
    if not ok:
        break

    # ------------ YOLO Pose Estimation -------------
    results = yolo_model.predict(frame, verbose=False)
    bgr = frame.copy()

    # ------------ Gambar Keypoints -------------
    if results and results[0].keypoints is not None:
        for kp in results[0].keypoints.xy:
            for x, y in kp.cpu().numpy():
                cv2.circle(bgr, (int(x), int(y)), 3, (0, 255, 0), -1)

    # =====================================================
    # ===============  (1)  INFERENCE  ====================
    # =====================================================
    keypoints = extract_keypoints(results[0])
    buf.append(keypoints)
    if len(buf) == SEQ_LEN and popup_phase is None:  # jangan infer saat popup
        prob = model.predict(np.expand_dims(buf, 0), verbose=0)[0]
        idx_pred = int(np.argmax(prob))
        last_pred = LABELS[idx_pred]
        last_conf = float(prob[idx_pred])

        target_lbl = WORKFLOW[idx_act]
        same_act = (last_pred == target_lbl) and (last_conf >= DETECT_THRESH)
        steady_ctr = steady_ctr + 1 if same_act else 0

        if state == 'Belum Bergerak' and steady_ctr >= STABLE_FRAMES:
            state = 'Sudah Setengah Gerakan'
            t_half = time.time()

        elif state == 'Sudah Setengah Gerakan':
            if steady_ctr >= STABLE_FRAMES and time.time() - t_half > 1.0:
                state = 'Gerakan Berhasil'
                score[target_lbl] = True
                popup_phase = 'result'  # ← tampilkan hasil, tunggu ENTER

        if last_conf < 0.20:
            state = 'Belum Bergerak'
            steady_ctr = 0

    # =====================================================
    # ===============  (2)  TIMER  ========================
    # =====================================================
    remaining = EXER_TIME - int(time.time() - t_ex_start)
    if popup_phase is None and remaining <= 0:
        state = 'Gerakan Gagal'
        score[WORKFLOW[idx_act]] = False
        popup_phase = 'result'

    # =====================================================
    # ===============  (3)  POP-UP  =======================
    # =====================================================
    if popup_phase is not None:
        remaining = max(0, remaining)  # ← mencegah nilai negatif

        key = cv2.waitKey(10) & 0xFF
        if popup_phase == 'result':
            # ---------- layar hasil ----------
            cv2.rectangle(bgr, (40, 140), (600, 270), (0, 0, 0), -1)
            cv2.putText(bgr,
                        f'Gerakan {WORKFLOW[idx_act]} : '
                        + ('BERHASIL' if score[WORKFLOW[idx_act]] else 'GAGAL'),
                        (60, 190), FONT, 0.8, (255, 255, 255), 2)

            if idx_act + 1 < len(WORKFLOW):
                cv2.putText(bgr, 'Tekan ENTER untuk lanjut',
                            (60, 230), FONT, 0.7, (0, 255, 255), 2)
            else:
                cv2.putText(bgr, 'Sesi selesai, tekan ESC untuk keluar',
                            (60, 230), FONT, 0.7, (0, 255, 255), 2)

            # -------- tunggu ENTER ----------
            if key in (13, 10):  # ENTER key
                popup_phase = 'prep'
                popup_start = time.time()

        elif popup_phase == 'prep':
            # ---------- hitung mundur ----------
            elap = time.time() - popup_start
            cnt = POPUP_TIME - int(elap)

            cv2.rectangle(bgr, (40, 140), (600, 270), (0, 0, 0), -1)
            cv2.putText(bgr, f'Siapkan gerakan : {WORKFLOW[idx_act+1]}',
                        (60, 190), FONT, 0.7, (255, 255, 255), 2)
            cv2.putText(bgr, f'Mulai dalam {cnt:02d} dtk',
                        (60, 230), FONT, 0.9, (0, 255, 255), 2)

            if elap >= POPUP_TIME:
                # reset ke gerakan berikutnya
                idx_act += 1
                if idx_act == len(WORKFLOW):
                    break
                state = 'Belum Bergerak'
                steady_ctr = 0
                buf.clear()
                t_ex_start = time.time()
                popup_phase = None

        cv2.imshow('Rehab-Assist', bgr)
        if key == 27:  # ESC
            break
        continue

    # =====================================================
    # ===============  (4)  HUD  ==========================
    # =====================================================
    cv2.rectangle(bgr, (0, 0), (640, 60), (0, 0, 0), -1)
    cv2.putText(bgr,
                f'Aksi: {WORKFLOW[idx_act]}   |   Timer: {remaining:02d}s',
                (10, 25), FONT, 0.6, (255, 255, 255), 2)

    det_txt = f"{last_pred if last_pred != '-' else '-'} ({last_conf*100:4.0f}%)"
    cv2.putText(bgr,
                f'Deteksi: {det_txt}',
                (10, 50), FONT, 0.6, (0, 255, 255), 2)

    cv2.rectangle(bgr, (0, 440), (640, 480), (0, 0, 0), -1)
    cv2.putText(bgr, f'Status: {state}', (10, 470), FONT, 0.7, (0, 255, 255), 2)

    key = cv2.waitKey(10) & 0xFF
    if key == 27:  # ESC
        break

    cv2.imshow('Rehab-Assist', bgr)

cap.release()
cv2.destroyAllWindows()

# %%
print('Skor akhir:')
for act in WORKFLOW:  # Menggunakan WORKFLOW karena urutan aksi latihan sudah ditentukan
    status = "✓" if score[act] else "✗"
    print(f'{act:<25}: {status}')
# Out:
# Skor akhir:
# Angkat Tangan            : ✗

# %%
print("Probabilitas per gerakan:")
for label, p in zip(LABELS, prob):
    print(f"{label}: {p:.4f}")
# Out:
# Probabilitas per gerakan:
# Angkat Pinggul: 0.0028
# Angkat Tangan: 0.0391
# Lutut Turun: 0.0637
# Naikan Kepalan Kedepan: 0.8888
# Rentangkan: 0.0057

# %%
pip freeze requirements.txt

# %%
# DETEKSI 1 GERAKAN 
import cv2
import numpy as np
import time
from ultralytics import YOLO
from tensorflow.keras.models import load_model
from gesture_feedback import (feedback_kaki_ke_belakang, feedback_lutut_turun, 
                              feedback_naikan_kepalan_kedepan, feedback_pinggul_naik, feedback_rentangkan)

# ---------- Load Model LSTM ----------
MODEL_PATH = 'lstm_best.keras'
model = load_model(MODEL_PATH)

# ---------- Inisialisasi Model YOLO ----------
yolo_model = YOLO('yolov8n-pose.pt')

# ---------- Mapping Gesture ke Feedback ----------
gesture_feedback_map = {
    "kaki_ke_belakang": feedback_kaki_ke_belakang,
    "lutut_turun": feedback_lutut_turun,
    "naikan_kepalan_kedepan": feedback_naikan_kepalan_kedepan,
    "pinggul_naik": feedback_pinggul_naik,
    "rentangkan": feedback_rentangkan,
}

# ---------- Pilih Gesture yang Ingin Dicek ----------
gesture_to_check = "Rentangkan"  # Ganti sesuai kebutuhan

# ---------- Parameter Inferensi ----------
SEQ_LEN = 30  # Panjang history gerakan
DETECT_THRESH = 0.60  # Ambang batas keyakinan deteksi

buf = []  # Buffer untuk menyimpan urutan keypoints

# ---------- Fungsi Ekstraksi Keypoints ----------
def extract_yolo_keypoints(results):
    # Always return a fixed-length array (34,) for 17 keypoints [x, y]
    num_kpts = 17 * 2
    if results is None or results.keypoints is None:
        return np.zeros(num_kpts, dtype='float32')
    keypoints = results.keypoints.xy[0].cpu().numpy().flatten()
    # Pad or slice to ensure fixed length
    if keypoints.shape[0] < num_kpts:
        keypoints = np.pad(keypoints, (0, num_kpts - keypoints.shape[0]), mode='constant')
    elif keypoints.shape[0] > num_kpts:
        keypoints = keypoints[:num_kpts]
    return keypoints.astype('float32')


# ---------- Jalankan Kamera dan Deteksi Gesture ----------
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = yolo_model.predict(frame, verbose=False)
    keypoints = extract_yolo_keypoints(results[0])  # Ambil keypoints
    buf.append(keypoints)

    # Simpan hanya SEQ_LEN frame terakhir
    if len(buf) > SEQ_LEN:
        buf.pop(0)

    # ---------- Lakukan Inferensi Menggunakan LSTM ----------
    if len(buf) == SEQ_LEN:
        prob = model.predict(np.expand_dims(buf, axis=0), verbose=0)[0]
        idx_pred = int(np.argmax(prob))
        last_conf = float(prob[idx_pred])

        # ---------- Berikan Feedback ----------
        feedback = "Belum Terdeteksi"
        if gesture_to_check in gesture_feedback_map:
            feedback_function = gesture_feedback_map[gesture_to_check]
            feedback = feedback_function(keypoints)

        # ---------- Tampilkan Hasil Inferensi ----------
        cv2.putText(frame, f'Gesture: {gesture_to_check}', (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)
        cv2.putText(frame, feedback, (10, 60),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

        prob_text = f'Confidence: {last_conf:.2f}'
        cv2.putText(frame, prob_text, (10, 90),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    # ---------- Gambar Keypoints ----------
    if keypoints is not None:
        for i in range(0, len(keypoints), 2):
            x, y = int(keypoints[i]), int(keypoints[i + 1])
            cv2.circle(frame, (x, y), 3, (0, 255, 0), -1)

    cv2.imshow('Gesture Feedback', frame)

    if cv2.waitKey(5) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
